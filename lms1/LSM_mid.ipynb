# %% [markdown]
# ## Mid-Project 전처리
# 주제 : 포스트 코로나의 ott 서비스의 이용 행태 및 이용률 변화
# - ott 서비스 개괄적 소개
# - 영화관, tv 외 기타 매채(스마트폰/태블릿 등등) 이용 빈도 변화 이용률 현황
# - ott 와 비교
# - 결과 도출

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib.font_manager as fm
font_name=fm.FontProperties(fname='C:\\Windows\\Fonts\\malgun.ttf').get_name()
plt.rc('font',family=font_name)

import matplotlib as mlp
mlp.rcParams['axes.unicode_minus']=False

# %% [markdown]
# # 1. 가장 많이 이용하는 OTT 서비스 1순위

# %%
best_ott=pd.read_csv("data/가장_많이_이용하는_OTT_서비스_1순위.csv",header=[0,1], index_col=[0,1])
best_ott
# Out:
# 구분별(1)                 2020                                              \
# 구분별(1)              사례수 (명) 티빙(Tving) (%) 웨이브(Wavve)(구 푹(pooq) 옥수수) (%)
# 전체      소계           7434.0           4.4                           4.0
# 성별      남            3872.0           3.9                           3.9
#         여            3562.0           4.9                           4.0
# 연령      만10대미만        173.0           1.2                           0.0
#         만10-19세       825.0           3.8                           1.0
# ...                     ...           ...                           ...
# 가구주와의관계 손자.녀/그배우자      67.0           5.7                           0.9
#         부모(배우자부모포함)    20.0           0.0                          40.2
#         형제자매/그배우자      73.0           8.5                           1.8
#         기타친인척          10.0           0.0                           0.0
#         동거인             2.0           0.0                           0.0
#
# 구분별(1)                                                                      \
# 구분별(1)              KT 시즌(Seezn)(구 olleh tv 모바일) (%) U+ 모바일(구 U+비디오포털) (%)
# 전체      소계                                       1.0                   1.3
# 성별      남                                        1.1                   1.3
#         여                                        0.8                   1.3
# 연령      만10대미만                                   2.7                   0.0
#         만10-19세                                  0.5                   0.5
# ...                                              ...                   ...
# 가구주와의관계 손자.녀/그배우자                                0.0                   0.0
#         부모(배우자부모포함)                              0.0                   0.0
#         형제자매/그배우자                                0.0                   1.3
#         기타친인척                                    0.0                   0.0
#         동거인                                      0.0                   0.0
#
# 구분별(1)                                                                    \
# 구분별(1)              에브리온 TV (%) 네이버시리즈(구 네이버 N 스토어) (%) 곰TV (%) 넷플릭스 (%)
# 전체      소계                  0.0                     0.7     0.2      7.1
# 성별      남                   0.0                     0.7     0.2      6.5
#         여                   0.1                     0.6     0.1      7.8
# 연령      만10대미만              0.0                     0.0     0.0      0.9
#         만10-19세             0.0                     0.4     0.1      4.6
# ...                         ...                     ...     ...      ...
# 가구주와의관계 손자.녀/그배우자           0.0                     0.0     0.0      3.6
#         부모(배우자부모포함)         0.0                     0.0     0.0      0.0
#         형제자매/그배우자           0.0                     0.0     0.0     14.4
#         기타친인척               0.0                     0.0     0.0     11.3
#         동거인                 0.0                     0.0     0.0      0.0
#
# 구분별(1)                          ...                    2021                   \
# 구분별(1)              카카오 TV (%)  ... 네이버시리즈(구 네이버 N 스토어) (%) 곰TV (%) 넷플릭스 (%)
# 전체      소계                 1.6  ...                     0.3     0.2      8.8
# 성별      남                  1.6  ...                     0.3     0.2      8.1
#         여                  1.7  ...                     0.4     0.1      9.5
# 연령      만10대미만             0.0  ...                     0.0     0.0      6.2
#         만10-19세            1.3  ...                     0.1     0.2      6.8
# ...                        ...  ...                     ...     ...      ...
# 가구주와의관계 손자.녀/그배우자          0.6  ...                     0.0     0.0     10.0
#         부모(배우자부모포함)        0.0  ...                     0.0     0.0      0.0
#         형제자매/그배우자         10.5  ...                     0.0     0.0      7.1
#         기타친인척              0.0  ...                     0.0     0.0      0.0
#         동거인                0.0  ...                     0.0     0.0      0.0
#
# 구분별(1)                                                                      \
# 구분별(1)              카카오 TV (%) 유튜브 (%) 아마존 프라임 비디오 (%) 왓챠플레이 (%) 쿠팡플레이 (%)
# 전체      소계                 1.8    81.5             0.0       0.2       0.2
# 성별      남                  1.6    82.6             0.0       0.1       0.1
#         여                  2.0    80.3             0.0       0.3       0.3
# 연령      만10대미만             0.0    90.2             0.0       0.0       0.0
#         만10-19세            3.5    86.2             0.0       0.4       0.0
# ...                        ...     ...             ...       ...       ...
# 가구주와의관계 손자.녀/그배우자          3.0    86.6             0.0       0.0       0.0
#         부모(배우자부모포함)        0.0    85.0             0.0       0.0       0.0
#         형제자매/그배우자          0.2    82.8             0.0       0.0       0.0
#         기타친인척              0.0    79.0             0.0       0.0       0.0
#         동거인                0.0    20.1             0.0       0.0       0.0
#
# 구분별(1)
# 구분별(1)              아프리카 TV (%) 기타 (%)
# 전체      소계                  0.3    0.0
# 성별      남                   0.5    0.1
#         여                   0.1    0.0
# 연령      만10대미만              0.0    0.4
#         만10-19세             0.1    0.1
# ...                         ...    ...
# 가구주와의관계 손자.녀/그배우자           0.0    0.0
#         부모(배우자부모포함)         0.0    0.0
#         형제자매/그배우자           0.2    0.0
#         기타친인척               0.0    0.0
#         동거인                 0.0    0.0
#
# [85 rows x 29 columns]

# %%
## 컬럼 이름 정리

best_ott.columns =[["2020","2020","2020","2020","2020","2020","2020","2020","2020","2020","2020","2020","2020","2020",
                    "2021","2021","2021","2021","2021","2021","2021","2021","2021","2021","2021","2021","2021","2021","2021"], 
                   ["사례수","티빙(Tving)","웨이브(Wavve)(구 푹(pooq) 옥수수)","KT 시즌(Seezn)(구 olleh tv 모바일)",
                    "U+ 모바일(구 U+비디오포털)","에브리온 TV","네이버시리즈(구 네이버 N 스토어)","곰TV",
                    "넷플릭스","카카오 TV","유튜브프리미엄","아마존 프라임 비디오","왓챠플레이","기타",
                    "사례수","티빙(Tving)","웨이브(Wavve)(구 푹(pooq) 옥수수)","KT 시즌(Seezn)(구 olleh tv 모바일)",
                    "U+ 모바일(구 U+비디오포털)","네이버시리즈(구 네이버 N 스토어)","곰TV","넷플릭스","카카오 TV","유튜브프리미엄",
                    "아마존 프라임 비디오","왓챠플레이","쿠팡플레이","아프리카 TV","기타"]]

# %%
best_ott

# %% [markdown]
# ### 0.5 이하의 컬럼 그룹화

# %%
best_ott["2020","기타합계(2020)"]=sum([best_ott["2020"]["에브리온 TV"],best_ott["2020"]["왓챠플레이"],best_ott["2020"]["기타"], best_ott["2020"]["곰TV"], best_ott["2020"]["아마존 프라임 비디오"],best_ott["2020"]["KT 시즌(Seezn)(구 olleh tv 모바일)"],best_ott["2020"]["네이버시리즈(구 네이버 N 스토어)"]])
best_ott["2021","기타합계(2021)"]=sum([best_ott["2021"]["곰TV"],best_ott["2021"]["왓챠플레이"],best_ott["2021"]["쿠팡플레이"],best_ott["2021"]["아프리카 TV"],best_ott["2021"]["아마존 프라임 비디오"],best_ott["2021"]["KT 시즌(Seezn)(구 olleh tv 모바일)"],best_ott["2021"]["네이버시리즈(구 네이버 N 스토어)"], best_ott["2021"]["기타"]])

# %%
## 필요없는 컬럼 삭제

del (best_ott["2020", "에브리온 TV"],best_ott["2020","왓챠플레이"],best_ott["2020","기타"], 
     best_ott["2020","곰TV"], best_ott["2020","아마존 프라임 비디오"],best_ott["2020","KT 시즌(Seezn)(구 olleh tv 모바일)"],
     best_ott["2020","네이버시리즈(구 네이버 N 스토어)"])
del (best_ott["2021","곰TV"],best_ott["2021","왓챠플레이"],best_ott["2021","쿠팡플레이"],best_ott["2021","아프리카 TV"],
      best_ott["2021","아마존 프라임 비디오"],best_ott["2021","KT 시즌(Seezn)(구 olleh tv 모바일)"],
      best_ott["2021","네이버시리즈(구 네이버 N 스토어)"], best_ott["2021","기타"])

# %%
best_ott

# %%
## 컬럼 이름 정리

best_ott.columns =[["2020","2020","2020","2020","2020","2020","2020","2021",
                    "2021","2021","2021","2021","2021","2021","2020","2021"], 
                   ["사례수","티빙","웨이브",
                    "U+ 모바일","넷플릭스","카카오 TV","유튜브프리미엄",
                    "사례수","티빙","웨이브",
                    "U+ 모바일","넷플릭스","카카오 TV","유튜브프리미엄",
                    "기타합계","기타합계"]]

# %% [markdown]
# ### 인덱스 이름 수정을 위해 전치 후 다시 복귀

# %%
best_ott=best_ott.T

# %%
## 필요없는 컬럼 삭제

del (best_ott["학력1","미취학"],best_ott["학력1","초졸이하"],best_ott["학력1","중졸이하"],best_ott["학력1","고졸이하"],
     best_ott["학력1","대졸이하"],best_ott["학력1","대학원재학이상"])
del (best_ott["지역구분2", "시부"],best_ott["지역구분2", "군부"])
del (best_ott["종사상지위","임금근로자"],best_ott["종사상지위","고용주"],best_ott["종사상지위","단독자영업자"],
     best_ott["종사상지위","무급가족종사자"],best_ott["종사상지위","무직"])
del (best_ott["상세직업","관리자"],best_ott["상세직업","전문가및관련종사자"],best_ott["상세직업","사무종사자"],
     best_ott["상세직업","서비스종사자"],best_ott["상세직업","판매종사자"],best_ott["상세직업","농림어업종사자"],
     best_ott["상세직업","기능원및관련기능종사자"],best_ott["상세직업","장치기계조작및조립종사자"],best_ott["상세직업","단순노무종사자"],
     best_ott["상세직업","직업군인"],best_ott["상세직업","학생"],best_ott["상세직업","전업주부"],best_ott["상세직업","군인(직업군인제외)"],
     best_ott["상세직업","기타/무직"])
del (best_ott["주택형태","단독주택"],best_ott["주택형태","아파트"],best_ott["주택형태","연립주택빌라다세대주택"],
     best_ott["주택형태","비거주용건물내의주택"],best_ott["주택형태","기타"])
del (best_ott["가족구성","1인가구"],best_ott["가족구성","1세대가구"],best_ott["가족구성","2세대가구"],
     best_ott["가족구성","3세대가구"],best_ott["가족구성","기타"])
del (best_ott["가구주와의관계","가구주"],best_ott["가구주와의관계","가구주의배우자"],best_ott["가구주와의관계","가구주의자녀"],
     best_ott["가구주와의관계","자녀의배우자"],best_ott["가구주와의관계","손자.녀/그배우자"],best_ott["가구주와의관계","부모(배우자부모포함)"],
     best_ott["가구주와의관계","형제자매/그배우자"],best_ott["가구주와의관계","기타친인척"],best_ott["가구주와의관계","동거인"])

# %%
## 컬럼 정리

best_ott.columns=[["전체","성별","성별","연령","연령","연령","연령","연령","연령","연령","연령",
                "월평균소득","월평균소득","월평균소득","월평균소득","월평균소득","월평균소득","월평균소득","월평균소득",
                "지역","지역","지역","지역","지역","지역","지역","지역","지역","지역","지역","지역",
                "지역","지역","지역","지역","지역","가구원수","가구원수","가구원수"],
               ["소계","남","여","만10대미만","만10-19세","만20-29세","만30-39세","만40-49세","만50-59세","만60-69세","만70세이상",
                "소득없음","50만원미만","50-100만원미만","100-200만원미만","200-300만원미만","300-400만원미만","400-500만원미만","500만원이상",
                "서울","부산","대구","인천","광주","대전","울산","경기","강원","충북","충남","전북","전남","경북","경남","제주","세종",
                "1인가구","2인가구","3인이상가구"]]

# %%
## 원상복귀
ott_use=best_ott.T
ott_use
# Out:
#                      2020                                           2021       \
#                       사례수   티빙   웨이브 U+ 모바일  넷플릭스 카카오 TV 유튜브프리미엄     사례수   티빙
# 전체    소계           7434.0  4.4   4.0    1.3   7.1    1.6    79.1  8293.7  2.9
# 성별    남            3872.0  3.9   3.9    1.3   6.5    1.6    80.2  4283.5  2.1
#       여            3562.0  4.9   4.0    1.3   7.8    1.7    77.9  4010.2  3.8
# 연령    만10대미만        173.0  1.2   0.0    0.0   0.9    0.0    95.2   174.5  1.5
#       만10-19세       825.0  3.8   1.0    0.5   4.6    1.3    87.5   880.1  1.2
#       만20-29세      1378.0  6.3   3.8    0.9  13.1    1.9    71.8  1381.4  5.3
#       만30-39세      1420.0  4.3   8.1    1.5   9.5    1.2    73.0  1390.1  4.4
#       만40-49세      1481.0  5.2   4.3    2.5   7.7    1.0    76.3  1585.9  2.9
#       만50-59세      1373.0  3.8   2.0    0.8   3.8    2.1    85.1  1580.6  2.1
#       만60-69세       666.0  2.2   3.8    1.1   1.2    2.7    85.4  1025.7  1.1
#       만70세이상        119.0  1.1   4.1    1.8   0.0    3.6    86.1   275.5  0.6
# 월평균소득 소득없음         2477.0  4.7   2.3    0.9   5.5    1.0    83.3  2631.2  2.2
#       50만원미만        138.0  9.6   2.6    2.3   6.2    0.5    73.5   175.9  3.5
#       50-100만원미만    222.0  2.2   4.3    3.6   8.0    1.2    76.2   317.8  0.9
#       100-200만원미만  1120.0  4.9   4.7    0.8   5.2    4.1    78.4  1094.2  1.3
#       200-300만원미만  1961.0  4.2   5.0    0.9   8.6    1.3    78.1  2118.0  4.1
#       300-400만원미만  1026.0  3.6   5.6    2.5   9.5    1.3    73.8  1326.0  4.6
#       400-500만원미만   266.0  4.8   1.1    2.1  11.8    1.1    75.8   358.2  1.6
#       500만원이상       224.0  1.6   7.1    1.5   4.8    1.8    78.9   272.5  2.1
# 지역    서울           1482.0  4.4   6.2    2.9  12.3    2.2    69.6  1626.1  5.5
#       부산            524.0  0.2   0.7    0.7   5.2    1.1    90.4   555.7  0.6
#       대구            335.0  3.9   3.1    1.2   9.5    1.8    76.5   358.0  1.9
#       인천            452.0  1.9   3.5    0.3   5.1    0.8    86.5   499.5  1.9
#       광주            248.0  5.6   0.3    0.0   4.6    1.5    86.4   263.0  1.1
#       대전            213.0  1.3   4.0    0.0   6.3    3.0    82.9   219.8  0.0
#       울산            176.0  0.2   1.8    1.0   1.2    0.4    92.2   187.4  1.6
#       경기           1907.0  9.5   4.9    1.5   6.6    1.8    73.1  2226.8  4.2
#       강원            181.0  0.3   1.6    1.5   6.8    0.0    86.9   207.4  0.6
#       충북            264.0  2.2   1.2    0.1   7.7    2.0    84.6   279.8  0.4
#       충남            265.0  3.2   7.1    0.8   1.9    1.7    84.2   305.8  0.0
#       전북            262.0  2.2   0.4    0.3   9.6    2.0    85.2   292.8  3.4
#       전남            245.0  4.7   0.7    0.0   3.6    0.8    83.3   279.7  0.5
#       경북            291.0  0.8  11.0    1.1   4.4    0.8    79.0   318.2  4.0
#       경남            427.0  0.4   1.5    0.5   4.3    1.8    89.1   501.1  0.9
#       제주             83.0  0.3   2.9    1.4   3.7    0.0    84.6    84.5  1.0
#       세종             79.0  4.0   0.0    0.0   7.8    0.8    87.3    88.1  0.0
# 가구원수  1인가구          822.0  1.5   8.4    0.8   9.6    1.6    77.2   951.3  6.0
#       2인가구         1586.0  4.9   3.6    0.6   6.5    2.5    79.7  1947.3  2.9
#       3인이상가구       5027.0  4.7   3.4    1.6   6.9    1.4    79.2  5395.1  2.4
#
#                                                    2020 2021
#                    웨이브 U+ 모바일  넷플릭스 카카오 TV 유튜브프리미엄 기타합계 기타합계
# 전체    소계           2.3    0.9   8.8    1.8    81.5  2.5  1.7
# 성별    남            2.6    0.9   8.1    1.6    82.6  2.5  2.0
#       여            2.0    0.9   9.5    2.0    80.3  2.4  1.6
# 연령    만10대미만       0.6    0.0   6.2    0.0    90.2  2.7  1.6
#       만10-19세      0.8    0.3   6.8    3.5    86.2  1.4  1.1
#       만20-29세      1.5    0.5  17.1    1.4    70.3  2.0  3.7
#       만30-39세      5.4    0.8  11.3    2.1    74.2  2.4  1.8
#       만40-49세      3.4    1.6  11.1    2.0    77.4  3.1  1.5
#       만50-59세      1.5    1.0   4.7    1.6    87.8  2.4  1.2
#       만60-69세      0.8    1.2   1.3    0.3    94.2  3.7  1.0
#       만70세이상       1.1    0.3   0.4    2.3    94.0  3.3  1.4
# 월평균소득 소득없음         1.4    0.7   8.4    2.1    83.3  2.2  1.9
#       50만원미만       0.0    0.3   6.8    0.5    88.4  5.2  0.5
#       50-100만원미만   0.9    0.3   5.8    0.3    87.5  4.5  4.2
#       100-200만원미만  2.6    1.1   9.5    2.2    82.3  1.9  1.1
#       200-300만원미만  2.3    0.9   8.9    1.4    80.6  1.9  1.8
#       300-400만원미만  3.6    1.2   7.9    1.6    79.2  3.7  1.9
#       400-500만원미만  5.2    0.7  15.4    3.3    71.7  3.3  2.0
#       500만원이상      4.0    1.7   9.1    1.2    80.2  4.2  1.7
# 지역    서울           4.1    2.3   8.8    2.1    75.6  2.3  1.7
#       부산           0.4    0.2   5.3    0.5    92.8  1.8  0.2
#       대구           5.4    0.4  16.2    6.2    66.3  3.9  3.6
#       인천           2.9    0.3   7.9    0.7    84.2  2.0  2.2
#       광주           0.3    0.0   5.3    1.1    91.9  1.6  0.2
#       대전           0.1    0.0   9.4    1.2    88.6  2.4  0.7
#       울산           0.3    0.4   8.5    0.0    88.0  3.3  1.2
#       경기           3.0    1.1  11.4    2.6    74.8  2.5  2.8
#       강원           2.7    0.2   9.1    0.6    83.2  3.0  3.6
#       충북           0.7    0.0   6.4    0.9    91.6  2.3  0.1
#       충남           0.2    0.7   7.6    1.1    90.4  1.2  0.0
#       전북           1.6    0.1   2.9    3.2    88.4  0.3  0.5
#       전남           0.1    0.4   0.5    0.9    94.9  6.8  2.8
#       경북           1.6    1.1   3.7    0.8    86.6  2.9  2.2
#       경남           0.3    0.2   9.1    0.1    88.4  2.5  1.0
#       제주           3.9    0.0   6.0    0.2    85.8  7.1  3.2
#       세종           0.0    0.0  23.9    0.0    76.1  0.0  0.0
# 가구원수  1인가구         4.9    1.0  10.8    2.3    74.0  0.8  1.0
#       2인가구         1.4    1.1   6.7    0.9    86.1  2.2  1.0
#       3인이상가구       2.2    0.8   9.2    2.0    81.1  2.8  2.2

# %% [markdown]
# #### 기타컬럼이 뒤에있어서 년도별로 정렬?정리?!

# %%
ott_use=pd.concat([ott_use["2020"],ott_use["2021"]], axis=1)
ott_use
# Out:
#                       사례수   티빙   웨이브  U+ 모바일  넷플릭스  카카오 TV  유튜브프리미엄  기타합계  \
# 전체    소계           7434.0  4.4   4.0     1.3   7.1     1.6     79.1   2.5
# 성별    남            3872.0  3.9   3.9     1.3   6.5     1.6     80.2   2.5
#       여            3562.0  4.9   4.0     1.3   7.8     1.7     77.9   2.4
# 연령    만10대미만        173.0  1.2   0.0     0.0   0.9     0.0     95.2   2.7
#       만10-19세       825.0  3.8   1.0     0.5   4.6     1.3     87.5   1.4
#       만20-29세      1378.0  6.3   3.8     0.9  13.1     1.9     71.8   2.0
#       만30-39세      1420.0  4.3   8.1     1.5   9.5     1.2     73.0   2.4
#       만40-49세      1481.0  5.2   4.3     2.5   7.7     1.0     76.3   3.1
#       만50-59세      1373.0  3.8   2.0     0.8   3.8     2.1     85.1   2.4
#       만60-69세       666.0  2.2   3.8     1.1   1.2     2.7     85.4   3.7
#       만70세이상        119.0  1.1   4.1     1.8   0.0     3.6     86.1   3.3
# 월평균소득 소득없음         2477.0  4.7   2.3     0.9   5.5     1.0     83.3   2.2
#       50만원미만        138.0  9.6   2.6     2.3   6.2     0.5     73.5   5.2
#       50-100만원미만    222.0  2.2   4.3     3.6   8.0     1.2     76.2   4.5
#       100-200만원미만  1120.0  4.9   4.7     0.8   5.2     4.1     78.4   1.9
#       200-300만원미만  1961.0  4.2   5.0     0.9   8.6     1.3     78.1   1.9
#       300-400만원미만  1026.0  3.6   5.6     2.5   9.5     1.3     73.8   3.7
#       400-500만원미만   266.0  4.8   1.1     2.1  11.8     1.1     75.8   3.3
#       500만원이상       224.0  1.6   7.1     1.5   4.8     1.8     78.9   4.2
# 지역    서울           1482.0  4.4   6.2     2.9  12.3     2.2     69.6   2.3
#       부산            524.0  0.2   0.7     0.7   5.2     1.1     90.4   1.8
#       대구            335.0  3.9   3.1     1.2   9.5     1.8     76.5   3.9
#       인천            452.0  1.9   3.5     0.3   5.1     0.8     86.5   2.0
#       광주            248.0  5.6   0.3     0.0   4.6     1.5     86.4   1.6
#       대전            213.0  1.3   4.0     0.0   6.3     3.0     82.9   2.4
#       울산            176.0  0.2   1.8     1.0   1.2     0.4     92.2   3.3
#       경기           1907.0  9.5   4.9     1.5   6.6     1.8     73.1   2.5
#       강원            181.0  0.3   1.6     1.5   6.8     0.0     86.9   3.0
#       충북            264.0  2.2   1.2     0.1   7.7     2.0     84.6   2.3
#       충남            265.0  3.2   7.1     0.8   1.9     1.7     84.2   1.2
#       전북            262.0  2.2   0.4     0.3   9.6     2.0     85.2   0.3
#       전남            245.0  4.7   0.7     0.0   3.6     0.8     83.3   6.8
#       경북            291.0  0.8  11.0     1.1   4.4     0.8     79.0   2.9
#       경남            427.0  0.4   1.5     0.5   4.3     1.8     89.1   2.5
#       제주             83.0  0.3   2.9     1.4   3.7     0.0     84.6   7.1
#       세종             79.0  4.0   0.0     0.0   7.8     0.8     87.3   0.0
# 가구원수  1인가구          822.0  1.5   8.4     0.8   9.6     1.6     77.2   0.8
#       2인가구         1586.0  4.9   3.6     0.6   6.5     2.5     79.7   2.2
#       3인이상가구       5027.0  4.7   3.4     1.6   6.9     1.4     79.2   2.8
#
#                       사례수   티빙  웨이브  U+ 모바일  넷플릭스  카카오 TV  유튜브프리미엄  기타합계
# 전체    소계           8293.7  2.9  2.3     0.9   8.8     1.8     81.5   1.7
# 성별    남            4283.5  2.1  2.6     0.9   8.1     1.6     82.6   2.0
#       여            4010.2  3.8  2.0     0.9   9.5     2.0     80.3   1.6
# 연령    만10대미만        174.5  1.5  0.6     0.0   6.2     0.0     90.2   1.6
#       만10-19세       880.1  1.2  0.8     0.3   6.8     3.5     86.2   1.1
#       만20-29세      1381.4  5.3  1.5     0.5  17.1     1.4     70.3   3.7
#       만30-39세      1390.1  4.4  5.4     0.8  11.3     2.1     74.2   1.8
#       만40-49세      1585.9  2.9  3.4     1.6  11.1     2.0     77.4   1.5
#       만50-59세      1580.6  2.1  1.5     1.0   4.7     1.6     87.8   1.2
#       만60-69세      1025.7  1.1  0.8     1.2   1.3     0.3     94.2   1.0
#       만70세이상        275.5  0.6  1.1     0.3   0.4     2.3     94.0   1.4
# 월평균소득 소득없음         2631.2  2.2  1.4     0.7   8.4     2.1     83.3   1.9
#       50만원미만        175.9  3.5  0.0     0.3   6.8     0.5     88.4   0.5
#       50-100만원미만    317.8  0.9  0.9     0.3   5.8     0.3     87.5   4.2
#       100-200만원미만  1094.2  1.3  2.6     1.1   9.5     2.2     82.3   1.1
#       200-300만원미만  2118.0  4.1  2.3     0.9   8.9     1.4     80.6   1.8
#       300-400만원미만  1326.0  4.6  3.6     1.2   7.9     1.6     79.2   1.9
#       400-500만원미만   358.2  1.6  5.2     0.7  15.4     3.3     71.7   2.0
#       500만원이상       272.5  2.1  4.0     1.7   9.1     1.2     80.2   1.7
# 지역    서울           1626.1  5.5  4.1     2.3   8.8     2.1     75.6   1.7
#       부산            555.7  0.6  0.4     0.2   5.3     0.5     92.8   0.2
#       대구            358.0  1.9  5.4     0.4  16.2     6.2     66.3   3.6
#       인천            499.5  1.9  2.9     0.3   7.9     0.7     84.2   2.2
#       광주            263.0  1.1  0.3     0.0   5.3     1.1     91.9   0.2
#       대전            219.8  0.0  0.1     0.0   9.4     1.2     88.6   0.7
#       울산            187.4  1.6  0.3     0.4   8.5     0.0     88.0   1.2
#       경기           2226.8  4.2  3.0     1.1  11.4     2.6     74.8   2.8
#       강원            207.4  0.6  2.7     0.2   9.1     0.6     83.2   3.6
#       충북            279.8  0.4  0.7     0.0   6.4     0.9     91.6   0.1
#       충남            305.8  0.0  0.2     0.7   7.6     1.1     90.4   0.0
#       전북            292.8  3.4  1.6     0.1   2.9     3.2     88.4   0.5
#       전남            279.7  0.5  0.1     0.4   0.5     0.9     94.9   2.8
#       경북            318.2  4.0  1.6     1.1   3.7     0.8     86.6   2.2
#       경남            501.1  0.9  0.3     0.2   9.1     0.1     88.4   1.0
#       제주             84.5  1.0  3.9     0.0   6.0     0.2     85.8   3.2
#       세종             88.1  0.0  0.0     0.0  23.9     0.0     76.1   0.0
# 가구원수  1인가구          951.3  6.0  4.9     1.0  10.8     2.3     74.0   1.0
#       2인가구         1947.3  2.9  1.4     1.1   6.7     0.9     86.1   1.0
#       3인이상가구       5395.1  2.4  2.2     0.8   9.2     2.0     81.1   2.2

# %%
ott_use.columns =[["2020","2020","2020","2020","2020","2020","2020","2020",
                    "2021","2021","2021","2021","2021","2021","2021","2021"], 
                   ["사례수","티빙","웨이브",
                    "U+ 모바일","넷플릭스","카카오 TV","유튜브프리미엄","기타합계",
                    "사례수","티빙","웨이브",
                    "U+ 모바일","넷플릭스","카카오 TV","유튜브프리미엄","기타합계"]]

# %%
ott_use

# %% [markdown]
# #### *** 반복문 수행 ***

# %%
# ott 서비스 추출 

for i in ott_use["2020"].columns[1:]:
    print(i)
# Out:
# 티빙
# 웨이브
# U+ 모바일
# 넷플릭스
# 카카오 TV
# 유튜브프리미엄
# 기타합계

# %%
# 진짜 이 방법뿐이었을까...

ott_name=["티빙","티빙","티빙","티빙","티빙","티빙","티빙","티빙","티빙","티빙","티빙","티빙","티빙",
         "티빙","티빙","티빙","티빙","티빙","티빙","티빙","티빙","티빙","티빙","티빙","티빙","티빙",
         "티빙","티빙","티빙","티빙","티빙","티빙","티빙","티빙","티빙","티빙","티빙","티빙","티빙",
         "웨이브","웨이브","웨이브","웨이브","웨이브","웨이브","웨이브","웨이브","웨이브","웨이브","웨이브","웨이브","웨이브",
         "웨이브","웨이브","웨이브","웨이브","웨이브","웨이브","웨이브","웨이브","웨이브","웨이브","웨이브","웨이브","웨이브",
         "웨이브","웨이브","웨이브","웨이브","웨이브","웨이브","웨이브","웨이브","웨이브","웨이브","웨이브","웨이브","웨이브",
         "U+ 모바일","U+ 모바일","U+ 모바일","U+ 모바일","U+ 모바일","U+ 모바일","U+ 모바일","U+ 모바일","U+ 모바일","U+ 모바일","U+ 모바일","U+ 모바일","U+ 모바일",
         "U+ 모바일","U+ 모바일","U+ 모바일","U+ 모바일","U+ 모바일","U+ 모바일","U+ 모바일","U+ 모바일","U+ 모바일","U+ 모바일","U+ 모바일","U+ 모바일","U+ 모바일",
         "U+ 모바일","U+ 모바일","U+ 모바일","U+ 모바일","U+ 모바일","U+ 모바일","U+ 모바일","U+ 모바일","U+ 모바일","U+ 모바일","U+ 모바일","U+ 모바일","U+ 모바일",
         "넷플릭스","넷플릭스","넷플릭스","넷플릭스","넷플릭스","넷플릭스","넷플릭스","넷플릭스","넷플릭스","넷플릭스","넷플릭스","넷플릭스","넷플릭스",
         "넷플릭스","넷플릭스","넷플릭스","넷플릭스","넷플릭스","넷플릭스","넷플릭스","넷플릭스","넷플릭스","넷플릭스","넷플릭스","넷플릭스","넷플릭스",
         "넷플릭스","넷플릭스","넷플릭스","넷플릭스","넷플릭스","넷플릭스","넷플릭스","넷플릭스","넷플릭스","넷플릭스","넷플릭스","넷플릭스","넷플릭스",
         "카카오TV","카카오TV","카카오TV","카카오TV","카카오TV","카카오TV","카카오TV","카카오TV","카카오TV","카카오TV","카카오TV","카카오TV","카카오TV",
         "카카오TV","카카오TV","카카오TV","카카오TV","카카오TV","카카오TV","카카오TV","카카오TV","카카오TV","카카오TV","카카오TV","카카오TV","카카오TV",
         "카카오TV","카카오TV","카카오TV","카카오TV","카카오TV","카카오TV","카카오TV","카카오TV","카카오TV","카카오TV","카카오TV","카카오TV","카카오TV",
         "유튜브프리미엄","유튜브프리미엄","유튜브프리미엄","유튜브프리미엄","유튜브프리미엄","유튜브프리미엄","유튜브프리미엄","유튜브프리미엄","유튜브프리미엄","유튜브프리미엄","유튜브프리미엄","유튜브프리미엄","유튜브프리미엄",
         "유튜브프리미엄","유튜브프리미엄","유튜브프리미엄","유튜브프리미엄","유튜브프리미엄","유튜브프리미엄","유튜브프리미엄","유튜브프리미엄","유튜브프리미엄","유튜브프리미엄","유튜브프리미엄","유튜브프리미엄","유튜브프리미엄",
         "유튜브프리미엄","유튜브프리미엄","유튜브프리미엄","유튜브프리미엄","유튜브프리미엄","유튜브프리미엄","유튜브프리미엄","유튜브프리미엄","유튜브프리미엄","유튜브프리미엄","유튜브프리미엄","유튜브프리미엄","유튜브프리미엄",
         "기타합계","기타합계","기타합계","기타합계","기타합계","기타합계","기타합계","기타합계","기타합계","기타합계","기타합계","기타합계","기타합계",
         "기타합계","기타합계","기타합계","기타합계","기타합계","기타합계","기타합계","기타합계","기타합계","기타합계","기타합계","기타합계","기타합계",
         "기타합계","기타합계","기타합계","기타합계","기타합계","기타합계","기타합계","기타합계","기타합계","기타합계","기타합계","기타합계","기타합계"]

# %%
# 구분1

list1=[]
for i in ott_use["2020"].columns[1:]:
    for j in ((ott_use["2021"][i]-ott_use["2020"][i])/ott_use["2020"][i]*100).index:
        list1.append(j[0])
        
list1
# Out:
# ['전체',
#  '성별',
#  '성별',
#  '연령',
#  '연령',
#  '연령',
#  '연령',
#  '연령',
#  '연령',
#  '연령',
#  '연령',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '가구원수',
#  '가구원수',
#  '가구원수',
#  '전체',
#  '성별',
#  '성별',
#  '연령',
#  '연령',
#  '연령',
#  '연령',
#  '연령',
#  '연령',
#  '연령',
#  '연령',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '가구원수',
#  '가구원수',
#  '가구원수',
#  '전체',
#  '성별',
#  '성별',
#  '연령',
#  '연령',
#  '연령',
#  '연령',
#  '연령',
#  '연령',
#  '연령',
#  '연령',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '가구원수',
#  '가구원수',
#  '가구원수',
#  '전체',
#  '성별',
#  '성별',
#  '연령',
#  '연령',
#  '연령',
#  '연령',
#  '연령',
#  '연령',
#  '연령',
#  '연령',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '가구원수',
#  '가구원수',
#  '가구원수',
#  '전체',
#  '성별',
#  '성별',
#  '연령',
#  '연령',
#  '연령',
#  '연령',
#  '연령',
#  '연령',
#  '연령',
#  '연령',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '가구원수',
#  '가구원수',
#  '가구원수',
#  '전체',
#  '성별',
#  '성별',
#  '연령',
#  '연령',
#  '연령',
#  '연령',
#  '연령',
#  '연령',
#  '연령',
#  '연령',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '가구원수',
#  '가구원수',
#  '가구원수',
#  '전체',
#  '성별',
#  '성별',
#  '연령',
#  '연령',
#  '연령',
#  '연령',
#  '연령',
#  '연령',
#  '연령',
#  '연령',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '월평균소득',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '지역',
#  '가구원수',
#  '가구원수',
#  '가구원수']

# %%
#구분2

list2=[]
for i in ott_use["2020"].columns[1:]:
    for j in ((ott_use["2021"][i]-ott_use["2020"][i])/ott_use["2020"][i]*100).index:
        list2.append(j[1])
        
list2
# Out:
# ['소계',
#  '남',
#  '여',
#  '만10대미만',
#  '만10-19세',
#  '만20-29세',
#  '만30-39세',
#  '만40-49세',
#  '만50-59세',
#  '만60-69세',
#  '만70세이상',
#  '소득없음',
#  '50만원미만',
#  '50-100만원미만',
#  '100-200만원미만',
#  '200-300만원미만',
#  '300-400만원미만',
#  '400-500만원미만',
#  '500만원이상',
#  '서울',
#  '부산',
#  '대구',
#  '인천',
#  '광주',
#  '대전',
#  '울산',
#  '경기',
#  '강원',
#  '충북',
#  '충남',
#  '전북',
#  '전남',
#  '경북',
#  '경남',
#  '제주',
#  '세종',
#  '1인가구',
#  '2인가구',
#  '3인이상가구',
#  '소계',
#  '남',
#  '여',
#  '만10대미만',
#  '만10-19세',
#  '만20-29세',
#  '만30-39세',
#  '만40-49세',
#  '만50-59세',
#  '만60-69세',
#  '만70세이상',
#  '소득없음',
#  '50만원미만',
#  '50-100만원미만',
#  '100-200만원미만',
#  '200-300만원미만',
#  '300-400만원미만',
#  '400-500만원미만',
#  '500만원이상',
#  '서울',
#  '부산',
#  '대구',
#  '인천',
#  '광주',
#  '대전',
#  '울산',
#  '경기',
#  '강원',
#  '충북',
#  '충남',
#  '전북',
#  '전남',
#  '경북',
#  '경남',
#  '제주',
#  '세종',
#  '1인가구',
#  '2인가구',
#  '3인이상가구',
#  '소계',
#  '남',
#  '여',
#  '만10대미만',
#  '만10-19세',
#  '만20-29세',
#  '만30-39세',
#  '만40-49세',
#  '만50-59세',
#  '만60-69세',
#  '만70세이상',
#  '소득없음',
#  '50만원미만',
#  '50-100만원미만',
#  '100-200만원미만',
#  '200-300만원미만',
#  '300-400만원미만',
#  '400-500만원미만',
#  '500만원이상',
#  '서울',
#  '부산',
#  '대구',
#  '인천',
#  '광주',
#  '대전',
#  '울산',
#  '경기',
#  '강원',
#  '충북',
#  '충남',
#  '전북',
#  '전남',
#  '경북',
#  '경남',
#  '제주',
#  '세종',
#  '1인가구',
#  '2인가구',
#  '3인이상가구',
#  '소계',
#  '남',
#  '여',
#  '만10대미만',
#  '만10-19세',
#  '만20-29세',
#  '만30-39세',
#  '만40-49세',
#  '만50-59세',
#  '만60-69세',
#  '만70세이상',
#  '소득없음',
#  '50만원미만',
#  '50-100만원미만',
#  '100-200만원미만',
#  '200-300만원미만',
#  '300-400만원미만',
#  '400-500만원미만',
#  '500만원이상',
#  '서울',
#  '부산',
#  '대구',
#  '인천',
#  '광주',
#  '대전',
#  '울산',
#  '경기',
#  '강원',
#  '충북',
#  '충남',
#  '전북',
#  '전남',
#  '경북',
#  '경남',
#  '제주',
#  '세종',
#  '1인가구',
#  '2인가구',
#  '3인이상가구',
#  '소계',
#  '남',
#  '여',
#  '만10대미만',
#  '만10-19세',
#  '만20-29세',
#  '만30-39세',
#  '만40-49세',
#  '만50-59세',
#  '만60-69세',
#  '만70세이상',
#  '소득없음',
#  '50만원미만',
#  '50-100만원미만',
#  '100-200만원미만',
#  '200-300만원미만',
#  '300-400만원미만',
#  '400-500만원미만',
#  '500만원이상',
#  '서울',
#  '부산',
#  '대구',
#  '인천',
#  '광주',
#  '대전',
#  '울산',
#  '경기',
#  '강원',
#  '충북',
#  '충남',
#  '전북',
#  '전남',
#  '경북',
#  '경남',
#  '제주',
#  '세종',
#  '1인가구',
#  '2인가구',
#  '3인이상가구',
#  '소계',
#  '남',
#  '여',
#  '만10대미만',
#  '만10-19세',
#  '만20-29세',
#  '만30-39세',
#  '만40-49세',
#  '만50-59세',
#  '만60-69세',
#  '만70세이상',
#  '소득없음',
#  '50만원미만',
#  '50-100만원미만',
#  '100-200만원미만',
#  '200-300만원미만',
#  '300-400만원미만',
#  '400-500만원미만',
#  '500만원이상',
#  '서울',
#  '부산',
#  '대구',
#  '인천',
#  '광주',
#  '대전',
#  '울산',
#  '경기',
#  '강원',
#  '충북',
#  '충남',
#  '전북',
#  '전남',
#  '경북',
#  '경남',
#  '제주',
#  '세종',
#  '1인가구',
#  '2인가구',
#  '3인이상가구',
#  '소계',
#  '남',
#  '여',
#  '만10대미만',
#  '만10-19세',
#  '만20-29세',
#  '만30-39세',
#  '만40-49세',
#  '만50-59세',
#  '만60-69세',
#  '만70세이상',
#  '소득없음',
#  '50만원미만',
#  '50-100만원미만',
#  '100-200만원미만',
#  '200-300만원미만',
#  '300-400만원미만',
#  '400-500만원미만',
#  '500만원이상',
#  '서울',
#  '부산',
#  '대구',
#  '인천',
#  '광주',
#  '대전',
#  '울산',
#  '경기',
#  '강원',
#  '충북',
#  '충남',
#  '전북',
#  '전남',
#  '경북',
#  '경남',
#  '제주',
#  '세종',
#  '1인가구',
#  '2인가구',
#  '3인이상가구']

# %%
# 증감율

values=[]
for i in ott_use["2020"].columns[1:]:
    values.extend(((ott_use["2021"][i]-ott_use["2020"][i])/ott_use["2020"][i]*100).values)

# %%
values
# Out:
# [-34.0909090909091,
#  -46.15384615384615,
#  -22.448979591836743,
#  25.000000000000007,
#  -68.42105263157893,
#  -15.873015873015872,
#  2.32558139534885,
#  -44.23076923076923,
#  -44.73684210526315,
#  -50.0,
#  -45.45454545454546,
#  -53.191489361702125,
#  -63.541666666666664,
#  -59.09090909090909,
#  -73.46938775510205,
#  -2.380952380952394,
#  27.77777777777776,
#  -66.66666666666666,
#  31.25,
#  24.99999999999999,
#  199.99999999999997,
#  -51.28205128205129,
#  0.0,
#  -80.35714285714286,
#  -100.0,
#  700.0,
#  -55.78947368421052,
#  100.0,
#  -81.81818181818183,
#  -100.0,
#  54.54545454545453,
#  -89.36170212765957,
#  400.0,
#  125.0,
#  233.33333333333334,
#  -100.0,
#  300.0,
#  -40.81632653061225,
#  -48.93617021276596,
#  -42.50000000000001,
#  -33.33333333333333,
#  -50.0,
#  inf,
#  -19.999999999999996,
#  -60.526315789473685,
#  -33.33333333333333,
#  -20.930232558139533,
#  -25.0,
#  -78.94736842105263,
#  -73.17073170731707,
#  -39.130434782608695,
#  -100.0,
#  -79.06976744186046,
#  -44.680851063829785,
#  -54.0,
#  -35.71428571428571,
#  372.72727272727263,
#  -43.66197183098591,
#  -33.870967741935495,
#  -42.85714285714285,
#  74.19354838709678,
#  -17.142857142857146,
#  0.0,
#  -97.5,
#  -83.33333333333333,
#  -38.775510204081634,
#  68.75,
#  -41.66666666666667,
#  -97.18309859154928,
#  300.00000000000006,
#  -85.71428571428572,
#  -85.45454545454547,
#  -80.0,
#  34.48275862068966,
#  nan,
#  -41.666666666666664,
#  -61.111111111111114,
#  -35.29411764705881,
#  -30.76923076923077,
#  -30.76923076923077,
#  -30.76923076923077,
#  nan,
#  -40.0,
#  -44.44444444444445,
#  -46.666666666666664,
#  -36.0,
#  24.999999999999993,
#  9.09090909090908,
#  -83.33333333333333,
#  -22.22222222222223,
#  -86.95652173913044,
#  -91.66666666666667,
#  37.50000000000001,
#  0.0,
#  -52.0,
#  -66.66666666666667,
#  13.33333333333333,
#  -20.689655172413797,
#  -71.42857142857143,
#  -66.66666666666666,
#  0.0,
#  nan,
#  nan,
#  -60.0,
#  -26.66666666666666,
#  -86.66666666666667,
#  -100.0,
#  -12.50000000000001,
#  -66.66666666666666,
#  inf,
#  0.0,
#  -60.0,
#  -100.0,
#  nan,
#  24.999999999999993,
#  83.33333333333336,
#  -50.0,
#  23.943661971831002,
#  24.61538461538461,
#  21.7948717948718,
#  588.8888888888888,
#  47.82608695652175,
#  30.53435114503818,
#  18.947368421052637,
#  44.15584415584415,
#  23.6842105263158,
#  8.333333333333341,
#  inf,
#  52.727272727272734,
#  9.677419354838705,
#  -27.500000000000004,
#  82.6923076923077,
#  3.4883720930232642,
#  -16.84210526315789,
#  30.508474576271183,
#  89.58333333333334,
#  -28.455284552845526,
#  1.9230769230769162,
#  70.52631578947368,
#  54.901960784313744,
#  15.21739130434783,
#  49.206349206349216,
#  608.3333333333333,
#  72.72727272727273,
#  33.8235294117647,
#  -16.88311688311688,
#  299.99999999999994,
#  -69.79166666666666,
#  -86.11111111111111,
#  -15.909090909090912,
#  111.62790697674419,
#  62.16216216216215,
#  206.41025641025638,
#  12.50000000000001,
#  3.0769230769230793,
#  33.333333333333314,
#  12.499999999999996,
#  0.0,
#  17.647058823529417,
#  nan,
#  169.23076923076923,
#  -26.31578947368421,
#  75.00000000000001,
#  100.0,
#  -23.809523809523807,
#  -88.8888888888889,
#  -36.111111111111114,
#  110.00000000000001,
#  0.0,
#  -75.0,
#  -46.341463414634134,
#  7.692307692307682,
#  23.076923076923077,
#  199.99999999999994,
#  -33.333333333333336,
#  -4.545454545454549,
#  -54.545454545454554,
#  244.44444444444446,
#  -12.50000000000001,
#  -26.66666666666666,
#  -60.0,
#  -100.0,
#  44.44444444444445,
#  inf,
#  -55.00000000000001,
#  -35.29411764705881,
#  60.00000000000001,
#  12.499999999999996,
#  0.0,
#  -94.44444444444444,
#  inf,
#  -100.0,
#  43.749999999999986,
#  -64.0,
#  42.85714285714287,
#  3.0341340075853425,
#  2.9925187032418843,
#  3.0808729139922866,
#  -5.2521008403361344,
#  -1.4857142857142824,
#  -2.0891364902506964,
#  1.64383561643836,
#  1.4416775884665904,
#  3.1727379553466544,
#  10.30444964871194,
#  9.175377468060402,
#  0.0,
#  20.272108843537424,
#  14.829396325459312,
#  4.974489795918356,
#  3.201024327784891,
#  7.317073170731716,
#  -5.408970976253292,
#  1.6476552598225565,
#  8.620689655172415,
#  2.6548672566371585,
#  -13.333333333333336,
#  -2.658959537572251,
#  6.36574074074074,
#  6.875753920385994,
#  -4.555314533622563,
#  2.3255813953488413,
#  -4.257767548906792,
#  8.274231678486998,
#  7.363420427553448,
#  3.7558685446009425,
#  13.925570228091248,
#  9.620253164556955,
#  -0.7856341189674395,
#  1.4184397163120601,
#  -12.82932416953036,
#  -4.145077720207258,
#  8.030112923462976,
#  2.398989898989888,
#  -31.999999999999996,
#  -20.0,
#  -33.33333333333333,
#  -40.74074074074075,
#  -21.428571428571402,
#  84.99999999999999,
#  -25.00000000000001,
#  -51.61290322580645,
#  -50.000000000000014,
#  -72.97297297297297,
#  -57.57575757575758,
#  -13.636363636363647,
#  -90.38461538461539,
#  -6.6666666666666625,
#  -42.10526315789473,
#  -5.263157894736835,
#  -48.64864864864865,
#  -39.39393939393939,
#  -59.523809523809526,
#  -26.08695652173912,
#  -88.8888888888889,
#  -7.6923076923077,
#  10.000000000000009,
#  -87.5,
#  -70.83333333333334,
#  -63.636363636363626,
#  12.00000000000001,
#  20.000000000000004,
#  -95.65217391304347,
#  -100.0,
#  66.66666666666664,
#  -58.823529411764696,
#  -24.13793103448276,
#  -60.0,
#  -54.92957746478873,
#  nan,
#  24.999999999999993,
#  -54.545454545454554,
#  -21.428571428571416]

# %%
print(len(ott_name),len(list1),len(list2),len(values))
# Out:
# 270 273 273 273

# %%
df=pd.DataFrame({"ott서비스":ott_name,
                 "구분1":list1,
                 "구분2":list2,
                 "증감률":values})
df
# Out:
#     ott서비스   구분1      구분2        증감률
# 0       티빙    전체       소계 -34.090909
# 1       티빙    성별        남 -46.153846
# 2       티빙    성별        여 -22.448980
# 3       티빙    연령   만10대미만  25.000000
# 4       티빙    연령  만10-19세 -68.421053
# ..     ...   ...      ...        ...
# 268   기타합계    지역       제주 -54.929577
# 269   기타합계    지역       세종        NaN
# 270   기타합계  가구원수     1인가구  25.000000
# 271   기타합계  가구원수     2인가구 -54.545455
# 272   기타합계  가구원수   3인이상가구 -21.428571
#
# [273 rows x 4 columns]

# %%
df=df.set_index(["ott서비스","구분1","구분2"])
df
# Out:
#                            증감률
# ott서비스 구분1  구분2
# 티빙     전체   소계      -34.090909
#        성별   남       -46.153846
#             여       -22.448980
#        연령   만10대미만   25.000000
#             만10-19세 -68.421053
# ...                        ...
# 기타합계   지역   제주      -54.929577
#             세종             NaN
#        가구원수 1인가구     25.000000
#             2인가구    -54.545455
#             3인이상가구  -21.428571
#
# [273 rows x 1 columns]

# %%
# 각 ott 서비스별 증감률 - 여기서 필요한 컬럼 뽑아서 사용하기!

tving_v=df.loc["티빙"]
wavve_v=df.loc["웨이브"]
uplus_v=df.loc["U+ 모바일"]
netflix_v=df.loc["넷플릭스"]
kakao_v=df.loc["카카오TV"]
youtube_v=df.loc["유튜브프리미엄"]
atc_v=df.loc["기타합계"]

# %% [markdown]
# # 2. 이용시간

# %%
best_ott=pd.read_csv("data/OTT서비스_이용시간.csv", header=[0,1], index_col=[0,1])

# %%
## 컬럼 정리

best_ott.columns =[["2019","2019","2019","2019","2019","2019","2019","2020","2020","2020","2020","2020","2020","2020"], 
                   ["사례수","5분 미만","5분 이상 10분 미만","10분 이상 30분 미만","30분 이상 1시간 미만","1시간 이상 2시간 미만","2시간 이상",
                   "사례수","5분 미만","5분 이상 10분 미만","10분 이상 30분 미만","30분 이상 1시간 미만","1시간 이상 2시간 미만","2시간 이상"]]

# %% [markdown]
# ### 인덱스 이름 수정을 위해 전치 후 다시 복귀

# %%
best_ott=best_ott.T

# %%
## 필요없는 컬럼 삭제

del (best_ott["학력1","미취학"],best_ott["학력1","초졸이하"],best_ott["학력1","중졸이하"],best_ott["학력1","고졸이하"],
     best_ott["학력1","대졸이하"],best_ott["학력1","대학원재학이상"])
del (best_ott["지역구분2", "시부"],best_ott["지역구분2", "군부"])
del (best_ott["종사상지위","임금근로자"],best_ott["종사상지위","고용주"],best_ott["종사상지위","단독자영업자"],
     best_ott["종사상지위","무급가족종사자"],best_ott["종사상지위","무직"])
del (best_ott["상세직업","관리자"],best_ott["상세직업","전문가및관련종사자"],best_ott["상세직업","사무종사자"],
     best_ott["상세직업","서비스종사자"],best_ott["상세직업","판매종사자"],best_ott["상세직업","농림어업종사자"],
     best_ott["상세직업","기능원및관련기능종사자"],best_ott["상세직업","장치기계조작및조립종사자"],best_ott["상세직업","단순노무종사자"],
     best_ott["상세직업","직업군인"],best_ott["상세직업","학생"],best_ott["상세직업","전업주부"],best_ott["상세직업","군인(직업군인제외)"],
     best_ott["상세직업","기타/무직"])
del (best_ott["주택형태","단독주택"],best_ott["주택형태","아파트"],best_ott["주택형태","연립주택빌라다세대주택"],
     best_ott["주택형태","비거주용건물내의주택"],best_ott["주택형태","기타"])
del (best_ott["가족구성","1인가구"],best_ott["가족구성","1세대가구"],best_ott["가족구성","2세대가구"],
     best_ott["가족구성","3세대가구"],best_ott["가족구성","기타"])
del (best_ott["가구주와의관계","가구주"],best_ott["가구주와의관계","가구주의배우자"],best_ott["가구주와의관계","가구주의자녀"],
     best_ott["가구주와의관계","자녀의배우자"],best_ott["가구주와의관계","손자.녀/그배우자"],best_ott["가구주와의관계","부모(배우자부모포함)"],
     best_ott["가구주와의관계","형제자매/그배우자"],best_ott["가구주와의관계","기타친인척"],best_ott["가구주와의관계","동거인"])

# %%
## 컬럼 정리

best_ott.columns=[["전체","성별","성별","연령","연령","연령","연령","연령","연령","연령","연령",
                "월평균소득","월평균소득","월평균소득","월평균소득","월평균소득","월평균소득","월평균소득","월평균소득",
                "지역","지역","지역","지역","지역","지역","지역","지역","지역","지역","지역","지역",
                "지역","지역","지역","지역","지역","가구원수","가구원수","가구원수"],
               ["소계","남","여","만10대미만","만10-19세","만20-29세","만30-39세","만40-49세","만50-59세","만60-69세","만70세이상",
                "소득없음","50만원미만","50-100만원미만","100-200만원미만","200-300만원미만","300-400만원미만","400-500만원미만","500만원이상",
                "서울","부산","대구","인천","광주","대전","울산","경기","강원","충북","충남","전북","전남","경북","경남","제주","세종",
                "1인가구","2인가구","3인이상가구"]]

# %%
## 원상복귀
ott_time=best_ott.T
ott_time
# Out:
#                      2019                                                 \
#                       사례수 5분 미만 5분 이상 10분 미만 10분 이상 30분 미만 30분 이상 1시간 미만
# 전체    소계           4457.7   1.1          7.3          43.3          25.8
# 성별    남            2375.6   0.9          7.0          44.0          24.8
#       여            2082.1   1.4          7.8          42.5          27.0
# 연령    만10대미만         80.6   4.5          3.5          42.5          31.4
#       만10-19세       501.5   0.9          4.6          32.8          25.6
#       만20-29세      1022.5   0.5          3.8          34.0          28.3
#       만30-39세       978.7   1.3          7.0          46.5          26.5
#       만40-49세       867.8   1.2          6.1          44.2          29.2
#       만50-59세       683.8   0.7         11.8          53.0          21.7
#       만60-69세       273.7   2.8         17.6          59.6          12.5
#       만70세이상         49.1   3.7         22.7          41.6          25.6
# 월평균소득 소득없음         1537.6   1.3          6.6          40.0          26.7
#       50만원미만        105.8   0.0         19.6          25.8          22.0
#       50-100만원미만    136.8   4.0          4.3          45.4          24.3
#       100-200만원미만   800.5   1.6          9.7          45.9          26.5
#       200-300만원미만  1081.3   0.8          7.3          44.8          27.7
#       300-400만원미만   504.8   0.8          6.2          53.4          20.1
#       400-500만원미만   173.2   0.0          4.1          35.6          21.1
#       500만원이상       117.7   0.0          3.4          36.0          29.4
# 지역    서울            699.2   0.2          2.6          41.2          24.9
#       부산            393.5   1.2          6.1          56.5          29.2
#       대구            174.1   0.4          3.0          35.7          19.1
#       인천            245.4   0.0          0.4          36.7          27.0
#       광주            109.9   0.0         12.8          45.5          35.9
#       대전            230.3   3.2         20.5          44.3          24.4
#       울산            150.5   0.4          7.9          69.3          11.8
#       경기           1040.9   0.1          2.1          34.5          31.1
#       강원            105.1   2.1         11.8          30.6          18.9
#       충북            249.7   1.4          7.0          59.1          28.8
#       충남            311.6   2.0          9.2          45.7          25.1
#       전북            139.4  14.2         26.2          41.2          16.8
#       전남             45.0   2.7         23.6          33.0          27.4
#       경북            135.2   0.5          8.1          26.9          19.1
#       경남            323.3   0.3         17.0          56.9          19.8
#       제주             58.9   0.0         12.3          19.1          32.0
#       세종             45.6   0.0          9.7          56.8          24.7
# 가구원수  1인가구          441.3   2.3         10.8          47.9          27.9
#       2인가구          919.5   1.7         13.3          49.0          22.3
#       3인이상가구       3096.9   0.8          5.0          41.0          26.6
#
#                                           2020                     \
#                   1시간 이상 2시간 미만 2시간 이상     사례수 5분 미만 5분 이상 10분 미만
# 전체    소계                   14.8    7.6  7434.0   0.2          2.0
# 성별    남                    16.4    7.0  3872.0   0.2          2.1
#       여                    13.0    8.4  3562.0   0.1          2.0
# 연령    만10대미만               13.4    4.8   173.0   0.0          0.2
#       만10-19세              24.0   12.1   825.0   0.1          1.1
#       만20-29세              18.2   15.3  1378.0   0.1          0.6
#       만30-39세              13.6    5.0  1420.0   0.1          1.1
#       만40-49세              14.7    4.6  1481.0   0.4          1.6
#       만50-59세               8.7    4.1  1373.0   0.2          3.8
#       만60-69세               6.4    1.2   666.0   0.1          5.4
#       만70세이상                6.4    0.0   119.0   0.0          3.4
# 월평균소득 소득없음                 16.2    9.3  2477.0   0.1          1.7
#       50만원미만               24.9    7.7   138.0   0.0          2.5
#       50-100만원미만           12.4    9.5   222.0   0.0          0.6
#       100-200만원미만          11.6    4.6  1120.0   0.1          3.8
#       200-300만원미만          12.7    6.7  1961.0   0.2          1.8
#       300-400만원미만          12.8    6.8  1026.0   0.3          1.5
#       400-500만원미만          26.5   12.8   266.0   0.0          1.6
#       500만원이상              21.9    9.2   224.0   0.0          1.9
# 지역    서울                   20.4   10.7  1482.0   0.1          1.9
#       부산                    6.7    0.3   524.0   0.0          1.7
#       대구                   29.6   12.2   335.0   0.4          3.8
#       인천                   22.2   13.7   452.0   0.0          4.2
#       광주                    4.8    1.1   248.0   0.0          0.2
#       대전                    6.9    0.8   213.0   0.0          4.2
#       울산                    7.9    2.7   176.0   0.0          0.0
#       경기                   18.9   13.3  1907.0   0.3          1.2
#       강원                   23.0   13.7   181.0   0.5          6.2
#       충북                    2.9    0.8   264.0   0.4          6.6
#       충남                   15.4    2.6   265.0   0.2          1.2
#       전북                    1.6    0.0   262.0   0.0          0.0
#       전남                   10.2    3.2   245.0   0.0          0.4
#       경북                   24.2   21.2   291.0   0.0          3.6
#       경남                    5.4    0.6   427.0   0.0          0.8
#       제주                   22.6   14.0    83.0   0.0          0.4
#       세종                    8.7    0.0    79.0   0.0          1.2
# 가구원수  1인가구                  5.9    5.3   822.0   0.0          2.2
#       2인가구                 11.8    1.8  1586.0   0.1          2.9
#       3인이상가구               16.9    9.7  5027.0   0.2          1.7
#
#
#                   10분 이상 30분 미만 30분 이상 1시간 미만 1시간 이상 2시간 미만 2시간 이상
# 전체    소계                   33.1          31.9          21.0   11.9
# 성별    남                    33.1          31.7          21.1   11.8
#       여                    33.1          32.0          20.8   12.0
# 연령    만10대미만               27.6          26.8          23.9   21.6
#       만10-19세              25.5          30.4          22.4   20.5
#       만20-29세              24.2          28.9          29.7   16.5
#       만30-39세              31.7          33.4          20.6   13.2
#       만40-49세              31.6          35.6          20.3   10.6
#       만50-59세              40.9          33.2          16.6    5.3
#       만60-69세              49.0          27.2          13.7    4.6
#       만70세이상               51.3          29.9          11.4    4.0
# 월평균소득 소득없음                 31.1          30.5          21.2   15.4
#       50만원미만               28.9          18.2          27.2   23.2
#       50-100만원미만           37.7          23.6          27.5   10.6
#       100-200만원미만          36.7          36.4          14.9    8.2
#       200-300만원미만          33.3          33.3          21.7    9.6
#       300-400만원미만          35.0          32.4          20.9    9.9
#       400-500만원미만          28.0          29.3          26.7   14.3
#       500만원이상              30.3          28.6          26.8   12.5
# 지역    서울                   27.8          30.8          23.8   15.6
#       부산                   66.1          23.9           7.7    0.5
#       대구                   15.3          26.0          33.8   20.7
#       인천                   40.6          21.0          14.0   20.2
#       광주                   20.0          62.1          12.6    5.2
#       대전                   47.2          26.9          18.0    3.8
#       울산                   43.1          38.8          16.1    2.1
#       경기                   24.8          29.5          28.9   15.3
#       강원                   15.7          27.0          26.5   24.2
#       충북                   61.1          25.1           6.5    0.4
#       충남                   50.2          28.3          19.3    0.8
#       전북                   22.9          65.7          11.4    0.0
#       전남                   26.6          56.5          12.8    3.7
#       경북                   27.1          23.1          24.6   21.6
#       경남                   47.1          34.9          15.3    1.9
#       제주                    3.5          17.7          30.1   48.3
#       세종                   47.7          39.4           3.7    8.0
# 가구원수  1인가구                 37.8          38.2          17.4    4.3
#       2인가구                 38.9          31.3          17.1    9.7
#       3인이상가구               30.5          31.0          22.8   13.8

# %% [markdown]
# #### 연령대

# %%
ott_time_2019=ott_time["2019"].T[1:]

# %%
ott_time_2019["연령"].plot(figsize=(12,8))
## 모든 연령대에서 10분이상 30분미만이 가장 많은 것을 볼 수 있다.
## 이동하거나 휴식시간에 OTT서비스를 이용한다는 것을 알 수 있다.
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 3. OTT 이용빈도

# %%
best_ott=pd.read_csv("data/OTT서비스_이용빈도.csv", header=[0,1], index_col=[0,1])

# %%
best_ott.columns
# Out:
# MultiIndex([('2019',       '사례수 (명)'),
#             ('2019',  '하루에도 여러번 (%)'),
#             ('2019',  '하루1번(매일) (%)'),
#             ('2019', '1주일에 5~6회 (%)'),
#             ('2019', '1주일에 3~4회 (%)'),
#             ('2019', '1주일에 1~2회 (%)'),
#             ('2019',     '월1~3회 (%)'),
#             ('2019',    '월1회 미만 (%)'),
#             ('2019',   '분기/연간1회 (%)'),
#             ('2020',       '사례수 (명)'),
#             ('2020',  '하루에도 여러번 (%)'),
#             ('2020',  '하루1번(매일) (%)'),
#             ('2020', '1주일에 5~6회 (%)'),
#             ('2020', '1주일에 3~4회 (%)'),
#             ('2020', '1주일에 1~2회 (%)'),
#             ('2020',     '월1~3회 (%)'),
#             ('2020',    '월1회 미만 (%)'),
#             ('2020',   '분기/연간1회 (%)'),
#             ('2021',       '사례수 (명)'),
#             ('2021',  '하루에도 여러번 (%)'),
#             ('2021',  '하루1번(매일) (%)'),
#             ('2021', '1주일에 5~6회 (%)'),
#             ('2021', '1주일에 3~4회 (%)'),
#             ('2021', '1주일에 1~2회 (%)'),
#             ('2021',     '월1~3회 (%)'),
#             ('2021',    '월1회 미만 (%)'),
#             ('2021',   '분기/연간1회 (%)')],
#            names=['구분별(1)', '구분별(1)'])

# %%
best_ott.columns =[["2019","2019","2019","2019","2019","2019","2019","2019","2019",
                    "2020","2020","2020","2020","2020","2020","2020","2020","2020",
                    "2021","2021","2021","2021","2021","2021","2021","2021","2021"], 
                   ["사례수","하루에도 여러번", "하루1번(매일)","1주일에 5~6회","1주일에 3~4회","1주일에 1~2회","월1~3회","월1회 미만","분기/연간1회",
                   "사례수","하루에도 여러번", "하루1번(매일)","1주일에 5~6회","1주일에 3~4회","1주일에 1~2회","월1~3회","월1회 미만","분기/연간1회",
                   "사례수","하루에도 여러번", "하루1번(매일)","1주일에 5~6회","1주일에 3~4회","1주일에 1~2회","월1~3회","월1회 미만","분기/연간1회"]]

# %%
best_ott=best_ott.T

# %%
del (best_ott["학력1","미취학"],best_ott["학력1","초졸이하"],best_ott["학력1","중졸이하"],best_ott["학력1","고졸이하"],
     best_ott["학력1","대졸이하"],best_ott["학력1","대학원재학이상"])
del (best_ott["지역구분2", "시부"],best_ott["지역구분2", "군부"])
del (best_ott["종사상지위","임금근로자"],best_ott["종사상지위","고용주"],best_ott["종사상지위","단독자영업자"],
     best_ott["종사상지위","무급가족종사자"],best_ott["종사상지위","무직"])
del (best_ott["상세직업","관리자"],best_ott["상세직업","전문가및관련종사자"],best_ott["상세직업","사무종사자"],
     best_ott["상세직업","서비스종사자"],best_ott["상세직업","판매종사자"],best_ott["상세직업","농림어업종사자"],
     best_ott["상세직업","기능원및관련기능종사자"],best_ott["상세직업","장치기계조작및조립종사자"],best_ott["상세직업","단순노무종사자"],
     best_ott["상세직업","직업군인"],best_ott["상세직업","학생"],best_ott["상세직업","전업주부"],best_ott["상세직업","군인(직업군인제외)"],
     best_ott["상세직업","기타/무직"])
del (best_ott["주택형태","단독주택"],best_ott["주택형태","아파트"],best_ott["주택형태","연립주택빌라다세대주택"],
     best_ott["주택형태","비거주용건물내의주택"],best_ott["주택형태","기타"])
del (best_ott["가족구성","1인가구"],best_ott["가족구성","1세대가구"],best_ott["가족구성","2세대가구"],
     best_ott["가족구성","3세대가구"],best_ott["가족구성","기타"])
del (best_ott["가구주와의관계","가구주"],best_ott["가구주와의관계","가구주의배우자"],best_ott["가구주와의관계","가구주의자녀"],
     best_ott["가구주와의관계","자녀의배우자"],best_ott["가구주와의관계","손자.녀/그배우자"],best_ott["가구주와의관계","부모(배우자부모포함)"],
     best_ott["가구주와의관계","형제자매/그배우자"],best_ott["가구주와의관계","기타친인척"],best_ott["가구주와의관계","동거인"])

# %%
best_ott.columns=[["전체","성별","성별","연령","연령","연령","연령","연령","연령","연령","연령",
                "월평균소득","월평균소득","월평균소득","월평균소득","월평균소득","월평균소득","월평균소득","월평균소득",
                "지역","지역","지역","지역","지역","지역","지역","지역","지역","지역","지역","지역",
                "지역","지역","지역","지역","지역","가구원수","가구원수","가구원수"],
               ["소계","남","여","만10대미만","만10-19세","만20-29세","만30-39세","만40-49세","만50-59세","만60-69세","만70세이상",
                "소득없음","50만원미만","50-100만원미만","100-200만원미만","200-300만원미만","300-400만원미만","400-500만원미만","500만원이상",
                "서울","부산","대구","인천","광주","대전","울산","경기","강원","충북","충남","전북","전남","경북","경남","제주","세종",
                "1인가구","2인가구","3인이상가구"]]

# %%
ott_bin=best_ott.T
ott_bin
# Out:
#                      2019                                                  \
#                       사례수 하루에도 여러번 하루1번(매일) 1주일에 5~6회 1주일에 3~4회 1주일에 1~2회
# 전체    소계           4457.7     20.8     13.4       8.5      13.8      28.9
# 성별    남            2375.6     21.8     12.8       8.8      14.2      27.8
#       여            2082.1     19.6     14.0       8.1      13.4      30.2
# 연령    만10대미만         80.6     22.4     18.5      10.3       5.8      16.0
#       만10-19세       501.5     34.5     12.6      12.3      11.1      19.9
#       만20-29세      1022.5     27.8     13.3       9.4      13.2      30.3
#       만30-39세       978.7     17.5     13.3       9.5      18.7      26.7
#       만40-49세       867.8     14.9     14.4       6.9      14.7      32.9
#       만50-59세       683.8     16.9     12.9       5.7      11.2      32.2
#       만60-69세       273.7     10.0     12.5       6.0      10.4      29.8
#       만70세이상         49.1     12.8      9.6       7.4       9.8      38.5
# 월평균소득 소득없음         1537.6     27.5     14.1       8.5      11.6      25.4
#       50만원미만        105.8     27.9     24.8       4.9       3.0      23.2
#       50-100만원미만    136.8     27.7      6.2      21.0       8.7      26.4
#       100-200만원미만   800.5     13.9     11.8       7.1      13.3      33.1
#       200-300만원미만  1081.3     16.0     12.6       9.0      18.4      30.1
#       300-400만원미만   504.8     17.3     15.2       8.6      15.4      31.3
#       400-500만원미만   173.2     22.2     11.1       2.9      14.4      34.1
#       500만원이상       117.7     21.5     14.8       9.7      12.8      26.8
# 지역    서울            699.2     22.1     12.2       5.4       9.5      33.6
#       부산            393.5     17.0     12.7      12.1      20.0      25.1
#       대구            174.1     35.3     13.8       3.9       6.7      21.7
#       인천            245.4     18.2      6.5       6.3      15.3      42.3
#       광주            109.9     17.0      6.0      14.8      24.6      25.3
#       대전            230.3     10.7     16.6      18.3      16.6      27.7
#       울산            150.5     11.1     15.5      12.0      22.9      22.6
#       경기           1040.9     25.7     16.3       4.9      12.1      27.6
#       강원            105.1     27.2      7.8       9.2      14.0      29.8
#       충북            249.7     14.1      2.7      18.5      23.0      27.6
#       충남            311.6     18.6     19.0      11.1      13.4      25.6
#       전북            139.4     15.5      0.5       4.5      18.2      33.1
#       전남             45.0     11.2     20.1       0.0      15.6      26.5
#       경북            135.2     53.8      9.5       2.0       5.3      15.3
#       경남            323.3     11.5     20.6      10.1      10.3      32.9
#       제주             58.9     15.8     30.9       3.6       2.6      24.6
#       세종             45.6      7.6      4.3      18.2      16.7      47.3
# 가구원수  1인가구          441.3     12.4     14.3       7.5      15.4      36.5
#       2인가구          919.5     16.9     14.2       9.1      14.0      29.8
#       3인이상가구       3096.9     23.1     13.0       8.4      13.5      27.6
#
#                                           2020  ...            2021           \
#                   월1~3회 월1회 미만 분기/연간1회     사례수  ... 분기/연간1회     사례수 하루에도 여러번
# 전체    소계           11.2    2.9     0.5  7434.0  ...     0.1  8293.7     36.5
# 성별    남            11.2    2.9     0.4  3872.0  ...     0.2  4283.5     36.7
#       여            11.1    3.0     0.6  3562.0  ...     0.0  4010.2     36.2
# 연령    만10대미만       22.5    4.5     0.0   173.0  ...     0.0   174.5     33.2
#       만10-19세       6.3    2.0     1.3   825.0  ...     0.2   880.1     50.0
#       만20-29세       4.7    1.1     0.1  1378.0  ...     0.0  1381.4     51.0
#       만30-39세      11.0    3.4     0.0  1420.0  ...     0.5  1390.1     35.4
#       만40-49세      12.5    3.1     0.6  1481.0  ...     0.0  1585.9     33.3
#       만50-59세      16.6    3.4     1.0  1373.0  ...     0.0  1580.6     29.6
#       만60-69세      23.8    7.5     0.0   666.0  ...     0.0  1025.7     25.1
#       만70세이상       11.7    4.0     6.2   119.0  ...     0.0   275.5     28.7
# 월평균소득 소득없음          9.6    2.6     0.7  2477.0  ...     0.1  2631.2     44.3
#       50만원미만       12.4    2.5     1.2   138.0  ...     0.0   175.9     39.3
#       50-100만원미만    5.5    2.1     2.4   222.0  ...     0.0   317.8     37.9
#       100-200만원미만  15.8    4.9     0.1  1120.0  ...     0.0  1094.2     26.1
#       200-300만원미만  10.8    2.9     0.2  1961.0  ...     0.0  2118.0     34.5
#       300-400만원미만  10.1    2.0     0.1  1026.0  ...     0.0  1326.0     32.3
#       400-500만원미만  12.9    2.2     0.2   266.0  ...     0.0   358.2     34.7
#       500만원이상      10.3    1.7     2.3   224.0  ...     3.1   272.5     37.9
# 지역    서울           14.2    2.5     0.5  1482.0  ...     0.0  1626.1     33.4
#       부산           10.4    2.3     0.5   524.0  ...     0.0   555.7     29.4
#       대구           11.1    6.3     1.0   335.0  ...     0.0   358.0     45.7
#       인천            9.9    1.3     0.2   452.0  ...     0.0   499.5     38.6
#       광주            9.5    2.9     0.0   248.0  ...     0.0   263.0     16.7
#       대전            6.2    2.4     1.3   213.0  ...     0.0   219.8     28.4
#       울산           15.0    0.7     0.0   176.0  ...     0.0   187.4     35.9
#       경기           10.5    2.1     0.7  1907.0  ...     0.4  2226.8     46.9
#       강원            7.5    4.5     0.0   181.0  ...     0.0   207.4     53.0
#       충북            9.3    4.9     0.0   264.0  ...     0.0   279.8     32.7
#       충남           10.7    1.6     0.0   265.0  ...     0.0   305.8     25.5
#       전북           10.0   16.2     2.0   262.0  ...     0.0   292.8     26.4
#       전남           21.6    5.1     0.0   245.0  ...     0.0   279.7      8.3
#       경북            9.8    3.8     0.5   291.0  ...     0.0   318.2     56.3
#       경남           13.5    1.1     0.0   427.0  ...     0.0   501.1     20.7
#       제주           17.3    4.6     0.7    83.0  ...     0.0    84.5     70.4
#       세종            4.5    0.5     0.9    79.0  ...     0.0    88.1     27.5
# 가구원수  1인가구         10.3    3.7     0.0   822.0  ...     0.0   951.3     30.8
#       2인가구         12.8    2.7     0.3  1586.0  ...     0.0  1947.3     29.1
#       3인이상가구       10.8    2.9     0.6  5027.0  ...     0.2  5395.1     40.2
#
#
#                   하루1번(매일) 1주일에 5~6회 1주일에 3~4회 1주일에 1~2회 월1~3회 월1회 미만 분기/연간1회
# 전체    소계              15.0       9.2      14.7      17.9   5.6    1.0     0.0
# 성별    남               15.8       9.3      13.8      18.1   5.0    1.3     0.0
#       여               14.1       9.2      15.7      17.7   6.3    0.6     0.0
# 연령    만10대미만          21.9       7.2      13.2      19.6   3.8    1.1     0.0
#       만10-19세         14.3      11.0      10.5      11.9   2.0    0.4     0.0
#       만20-29세         14.5       8.2      11.1      14.1   1.0    0.1     0.0
#       만30-39세         16.0      11.8      16.8      15.1   4.6    0.3     0.0
#       만40-49세         15.7       8.3      13.6      20.1   7.9    1.2     0.0
#       만50-59세         13.4       8.1      17.5      20.4   8.9    2.0     0.1
#       만60-69세         15.8       9.6      18.2      22.7   7.0    1.4     0.1
#       만70세이상          12.5       8.3      14.4      24.2   9.9    1.8     0.1
# 월평균소득 소득없음            14.2       9.1      13.4      14.1   4.3    0.7     0.0
#       50만원미만           7.2      10.2      11.3      21.1   8.5    2.4     0.0
#       50-100만원미만      11.9       8.1       9.2      27.0   5.7    0.2     0.0
#       100-200만원미만     14.1       9.3      17.7      24.7   6.6    1.5     0.0
#       200-300만원미만     17.7      10.1      16.4      14.6   5.7    1.0     0.0
#       300-400만원미만     15.4       9.2      14.5      21.1   6.8    0.7     0.0
#       400-500만원미만     14.6       7.6      14.5      20.6   7.4    0.6     0.0
#       500만원이상         12.8       7.5      12.4      21.4   4.2    3.4     0.5
# 지역    서울              14.4       9.6      14.0      20.3   8.0    0.4     0.0
#       부산              17.0       3.3       7.9      22.7  16.1    3.6     0.0
#       대구              18.4       5.1      10.5      14.7   2.9    2.2     0.4
#       인천              17.0      18.3      15.3       8.4   1.9    0.5     0.0
#       광주              11.9      16.7      24.5      26.6   3.2    0.4     0.0
#       대전               3.2      15.1      16.4      34.5   2.2    0.1     0.0
#       울산              37.9       9.5       5.4       6.4   2.9    2.0     0.0
#       경기              16.3       5.6      11.6      15.1   4.1    0.5     0.0
#       강원              19.6       8.6       6.0       8.9   2.9    1.0     0.0
#       충북              11.6      12.7      31.1      10.9   1.0    0.0     0.0
#       충남              13.4      17.5      22.1      18.5   2.9    0.2     0.0
#       전북               5.8      18.5      20.8      24.7   3.2    0.3     0.3
#       전남               7.2      13.9      35.3      28.4   4.7    2.0     0.1
#       경북              13.3       5.2       8.1       9.5   5.2    2.4     0.0
#       경남               7.8       7.6      21.0      28.5  12.2    2.1     0.0
#       제주              15.4       2.6       2.9       7.4   1.3    0.0     0.0
#       세종              53.8       7.4       6.7       4.6   0.0    0.0     0.0
# 가구원수  1인가구            18.4       8.6      11.5      23.9   5.4    1.4     0.0
#       2인가구            15.5       9.9      16.9      18.4   9.1    1.1     0.1
#       3인이상가구          14.2       9.1      14.5      16.7   4.4    0.8     0.0
#
# [39 rows x 27 columns]

# %%
del (ott_bin["2019","사례수"], ott_bin["2020","사례수"], ott_bin["2021","사례수"])
ott_bin
# Out:
#                       2019                                               \
#                   하루에도 여러번 하루1번(매일) 1주일에 5~6회 1주일에 3~4회 1주일에 1~2회 월1~3회
# 전체    소계              20.8     13.4       8.5      13.8      28.9  11.2
# 성별    남               21.8     12.8       8.8      14.2      27.8  11.2
#       여               19.6     14.0       8.1      13.4      30.2  11.1
# 연령    만10대미만          22.4     18.5      10.3       5.8      16.0  22.5
#       만10-19세         34.5     12.6      12.3      11.1      19.9   6.3
#       만20-29세         27.8     13.3       9.4      13.2      30.3   4.7
#       만30-39세         17.5     13.3       9.5      18.7      26.7  11.0
#       만40-49세         14.9     14.4       6.9      14.7      32.9  12.5
#       만50-59세         16.9     12.9       5.7      11.2      32.2  16.6
#       만60-69세         10.0     12.5       6.0      10.4      29.8  23.8
#       만70세이상          12.8      9.6       7.4       9.8      38.5  11.7
# 월평균소득 소득없음            27.5     14.1       8.5      11.6      25.4   9.6
#       50만원미만          27.9     24.8       4.9       3.0      23.2  12.4
#       50-100만원미만      27.7      6.2      21.0       8.7      26.4   5.5
#       100-200만원미만     13.9     11.8       7.1      13.3      33.1  15.8
#       200-300만원미만     16.0     12.6       9.0      18.4      30.1  10.8
#       300-400만원미만     17.3     15.2       8.6      15.4      31.3  10.1
#       400-500만원미만     22.2     11.1       2.9      14.4      34.1  12.9
#       500만원이상         21.5     14.8       9.7      12.8      26.8  10.3
# 지역    서울              22.1     12.2       5.4       9.5      33.6  14.2
#       부산              17.0     12.7      12.1      20.0      25.1  10.4
#       대구              35.3     13.8       3.9       6.7      21.7  11.1
#       인천              18.2      6.5       6.3      15.3      42.3   9.9
#       광주              17.0      6.0      14.8      24.6      25.3   9.5
#       대전              10.7     16.6      18.3      16.6      27.7   6.2
#       울산              11.1     15.5      12.0      22.9      22.6  15.0
#       경기              25.7     16.3       4.9      12.1      27.6  10.5
#       강원              27.2      7.8       9.2      14.0      29.8   7.5
#       충북              14.1      2.7      18.5      23.0      27.6   9.3
#       충남              18.6     19.0      11.1      13.4      25.6  10.7
#       전북              15.5      0.5       4.5      18.2      33.1  10.0
#       전남              11.2     20.1       0.0      15.6      26.5  21.6
#       경북              53.8      9.5       2.0       5.3      15.3   9.8
#       경남              11.5     20.6      10.1      10.3      32.9  13.5
#       제주              15.8     30.9       3.6       2.6      24.6  17.3
#       세종               7.6      4.3      18.2      16.7      47.3   4.5
# 가구원수  1인가구            12.4     14.3       7.5      15.4      36.5  10.3
#       2인가구            16.9     14.2       9.1      14.0      29.8  12.8
#       3인이상가구          23.1     13.0       8.4      13.5      27.6  10.8
#
#                                      2020           ...                 \
#                   월1회 미만 분기/연간1회 하루에도 여러번 하루1번(매일)  ... 월1회 미만 분기/연간1회
# 전체    소계             2.9     0.5     35.0     15.4  ...    1.7     0.1
# 성별    남              2.9     0.4     35.4     16.2  ...    1.7     0.2
#       여              3.0     0.6     34.6     14.6  ...    1.7     0.0
# 연령    만10대미만         4.5     0.0     45.2     19.2  ...    0.0     0.0
#       만10-19세        2.0     1.3     45.9     16.0  ...    1.2     0.2
#       만20-29세        1.1     0.1     45.9     17.4  ...    0.2     0.0
#       만30-39세        3.4     0.0     32.9     15.9  ...    1.5     0.5
#       만40-49세        3.1     0.6     30.1     14.4  ...    1.5     0.0
#       만50-59세        3.4     1.0     27.1     13.7  ...    2.5     0.0
#       만60-69세        7.5     0.0     28.4     15.4  ...    4.6     0.0
#       만70세이상         4.0     6.2     32.3      9.8  ...    4.6     0.0
# 월평균소득 소득없음           2.6     0.7     43.5     13.3  ...    1.3     0.1
#       50만원미만         2.5     1.2     54.8      9.2  ...    4.6     0.0
#       50-100만원미만     2.1     2.4     29.5     12.2  ...    2.8     0.0
#       100-200만원미만    4.9     0.1     30.2     11.5  ...    1.8     0.0
#       200-300만원미만    2.9     0.2     27.9     20.0  ...    1.5     0.0
#       300-400만원미만    2.0     0.1     30.6     16.4  ...    1.6     0.0
#       400-500만원미만    2.2     0.2     35.2     19.8  ...    1.0     0.0
#       500만원이상        1.7     2.3     41.0     15.6  ...    5.2     3.1
# 지역    서울             2.5     0.5     41.2     13.3  ...    0.6     0.0
#       부산             2.3     0.5     26.6     13.9  ...    2.4     0.0
#       대구             6.3     1.0     49.8     17.4  ...    4.3     0.0
#       인천             1.3     0.2     51.5     15.2  ...    0.6     0.0
#       광주             2.9     0.0     18.1     19.2  ...    0.4     0.0
#       대전             2.4     1.3      7.5     12.4  ...    0.5     0.0
#       울산             0.7     0.0     34.4     15.1  ...    4.1     0.0
#       경기             2.1     0.7     37.2     20.5  ...    1.5     0.4
#       강원             4.5     0.0     56.0     16.3  ...    0.8     0.0
#       충북             4.9     0.0     10.2     16.9  ...    0.1     0.0
#       충남             1.6     0.0     15.6     16.2  ...    3.3     0.0
#       전북            16.2     2.0     35.3     13.1  ...    0.0     0.0
#       전남             5.1     0.0      8.4      7.7  ...    2.1     0.0
#       경북             3.8     0.5     65.6     10.8  ...    7.1     0.0
#       경남             1.1     0.0     15.1      6.6  ...    3.1     0.0
#       제주             4.6     0.7     81.7      9.1  ...    0.0     0.0
#       세종             0.5     0.9     20.1     24.3  ...    0.0     0.0
# 가구원수  1인가구           3.7     0.0     26.7     18.1  ...    0.8     0.0
#       2인가구           2.7     0.3     30.8     12.2  ...    2.3     0.0
#       3인이상가구         2.9     0.6     37.7     16.0  ...    1.7     0.2
#
#                       2021                                               \
#                   하루에도 여러번 하루1번(매일) 1주일에 5~6회 1주일에 3~4회 1주일에 1~2회 월1~3회
# 전체    소계              36.5     15.0       9.2      14.7      17.9   5.6
# 성별    남               36.7     15.8       9.3      13.8      18.1   5.0
#       여               36.2     14.1       9.2      15.7      17.7   6.3
# 연령    만10대미만          33.2     21.9       7.2      13.2      19.6   3.8
#       만10-19세         50.0     14.3      11.0      10.5      11.9   2.0
#       만20-29세         51.0     14.5       8.2      11.1      14.1   1.0
#       만30-39세         35.4     16.0      11.8      16.8      15.1   4.6
#       만40-49세         33.3     15.7       8.3      13.6      20.1   7.9
#       만50-59세         29.6     13.4       8.1      17.5      20.4   8.9
#       만60-69세         25.1     15.8       9.6      18.2      22.7   7.0
#       만70세이상          28.7     12.5       8.3      14.4      24.2   9.9
# 월평균소득 소득없음            44.3     14.2       9.1      13.4      14.1   4.3
#       50만원미만          39.3      7.2      10.2      11.3      21.1   8.5
#       50-100만원미만      37.9     11.9       8.1       9.2      27.0   5.7
#       100-200만원미만     26.1     14.1       9.3      17.7      24.7   6.6
#       200-300만원미만     34.5     17.7      10.1      16.4      14.6   5.7
#       300-400만원미만     32.3     15.4       9.2      14.5      21.1   6.8
#       400-500만원미만     34.7     14.6       7.6      14.5      20.6   7.4
#       500만원이상         37.9     12.8       7.5      12.4      21.4   4.2
# 지역    서울              33.4     14.4       9.6      14.0      20.3   8.0
#       부산              29.4     17.0       3.3       7.9      22.7  16.1
#       대구              45.7     18.4       5.1      10.5      14.7   2.9
#       인천              38.6     17.0      18.3      15.3       8.4   1.9
#       광주              16.7     11.9      16.7      24.5      26.6   3.2
#       대전              28.4      3.2      15.1      16.4      34.5   2.2
#       울산              35.9     37.9       9.5       5.4       6.4   2.9
#       경기              46.9     16.3       5.6      11.6      15.1   4.1
#       강원              53.0     19.6       8.6       6.0       8.9   2.9
#       충북              32.7     11.6      12.7      31.1      10.9   1.0
#       충남              25.5     13.4      17.5      22.1      18.5   2.9
#       전북              26.4      5.8      18.5      20.8      24.7   3.2
#       전남               8.3      7.2      13.9      35.3      28.4   4.7
#       경북              56.3     13.3       5.2       8.1       9.5   5.2
#       경남              20.7      7.8       7.6      21.0      28.5  12.2
#       제주              70.4     15.4       2.6       2.9       7.4   1.3
#       세종              27.5     53.8       7.4       6.7       4.6   0.0
# 가구원수  1인가구            30.8     18.4       8.6      11.5      23.9   5.4
#       2인가구            29.1     15.5       9.9      16.9      18.4   9.1
#       3인이상가구          40.2     14.2       9.1      14.5      16.7   4.4
#
#
#                   월1회 미만 분기/연간1회
# 전체    소계             1.0     0.0
# 성별    남              1.3     0.0
#       여              0.6     0.0
# 연령    만10대미만         1.1     0.0
#       만10-19세        0.4     0.0
#       만20-29세        0.1     0.0
#       만30-39세        0.3     0.0
#       만40-49세        1.2     0.0
#       만50-59세        2.0     0.1
#       만60-69세        1.4     0.1
#       만70세이상         1.8     0.1
# 월평균소득 소득없음           0.7     0.0
#       50만원미만         2.4     0.0
#       50-100만원미만     0.2     0.0
#       100-200만원미만    1.5     0.0
#       200-300만원미만    1.0     0.0
#       300-400만원미만    0.7     0.0
#       400-500만원미만    0.6     0.0
#       500만원이상        3.4     0.5
# 지역    서울             0.4     0.0
#       부산             3.6     0.0
#       대구             2.2     0.4
#       인천             0.5     0.0
#       광주             0.4     0.0
#       대전             0.1     0.0
#       울산             2.0     0.0
#       경기             0.5     0.0
#       강원             1.0     0.0
#       충북             0.0     0.0
#       충남             0.2     0.0
#       전북             0.3     0.3
#       전남             2.0     0.1
#       경북             2.4     0.0
#       경남             2.1     0.0
#       제주             0.0     0.0
#       세종             0.0     0.0
# 가구원수  1인가구           1.4     0.0
#       2인가구           1.1     0.1
#       3인이상가구         0.8     0.0
#
# [39 rows x 24 columns]

# %%
# 연령별 이용빈도 : 젊을수록 이용빈도가 잦고(하루에 여러번), 나이가 많을수록 1주일에 1-2회가 많음을 볼 수 있다
ott_bin["2019"].loc["연령"].plot(kind='barh', stacked=True,figsize=(15,10))
# Out:
# <AxesSubplot:>

# %%
# 가구원수가 많을수록 이용빈도가 잦음을 볼 수 있다.
# 이를 통해 계정을 공유하는 사람이 많다는 것을 알 수가 있나,,?
ott_bin["2019"].loc["가구원수"].plot(kind='barh', stacked=True,figsize=(10,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 4. 유료결제
#    - 없다가 너무 많아서 필요 없을듯

# %%
best_ott=pd.read_csv("data/OTT서비스_유료결제_이용여부.csv", header=[0,1], index_col=[0,1])

# %%
best_ott.columns
# Out:
# MultiIndex([('2019', '사례수 (명)'),
#             ('2019',  '있다 (%)'),
#             ('2019',  '없다 (%)'),
#             ('2020', '사례수 (명)'),
#             ('2020',  '있다 (%)'),
#             ('2020',  '없다 (%)')],
#            names=['구분별(1)', '구분별(1)'])

# %%
best_ott.columns=[["2019","2019","2019","2020","2020","2020"],
                 ["사례수","있다","없다","사례수","있다","없다"]]

# %%
best_ott=best_ott.T

# %%
del (best_ott["학력1","미취학"],best_ott["학력1","초졸이하"],best_ott["학력1","중졸이하"],best_ott["학력1","고졸이하"],
     best_ott["학력1","대졸이하"],best_ott["학력1","대학원재학이상"])
del (best_ott["지역구분2", "시부"],best_ott["지역구분2", "군부"])
del (best_ott["종사상지위","임금근로자"],best_ott["종사상지위","고용주"],best_ott["종사상지위","단독자영업자"],
     best_ott["종사상지위","무급가족종사자"],best_ott["종사상지위","무직"])
del (best_ott["상세직업","관리자"],best_ott["상세직업","전문가및관련종사자"],best_ott["상세직업","사무종사자"],
     best_ott["상세직업","서비스종사자"],best_ott["상세직업","판매종사자"],best_ott["상세직업","농림어업종사자"],
     best_ott["상세직업","기능원및관련기능종사자"],best_ott["상세직업","장치기계조작및조립종사자"],best_ott["상세직업","단순노무종사자"],
     best_ott["상세직업","직업군인"],best_ott["상세직업","학생"],best_ott["상세직업","전업주부"],best_ott["상세직업","군인(직업군인제외)"],
     best_ott["상세직업","기타/무직"])
del (best_ott["주택형태","단독주택"],best_ott["주택형태","아파트"],best_ott["주택형태","연립주택빌라다세대주택"],
     best_ott["주택형태","비거주용건물내의주택"],best_ott["주택형태","기타"])
del (best_ott["가족구성","1인가구"],best_ott["가족구성","1세대가구"],best_ott["가족구성","2세대가구"],
     best_ott["가족구성","3세대가구"],best_ott["가족구성","기타"])
del (best_ott["가구주와의관계","가구주"],best_ott["가구주와의관계","가구주의배우자"],best_ott["가구주와의관계","가구주의자녀"],
     best_ott["가구주와의관계","자녀의배우자"],best_ott["가구주와의관계","손자.녀/그배우자"],best_ott["가구주와의관계","부모(배우자부모포함)"],
     best_ott["가구주와의관계","형제자매/그배우자"],best_ott["가구주와의관계","기타친인척"],best_ott["가구주와의관계","동거인"])

# %%
best_ott.columns=[["전체","성별","성별","연령","연령","연령","연령","연령","연령","연령","연령",
                "월평균소득","월평균소득","월평균소득","월평균소득","월평균소득","월평균소득","월평균소득","월평균소득",
                "지역","지역","지역","지역","지역","지역","지역","지역","지역","지역","지역","지역",
                "지역","지역","지역","지역","지역","가구원수","가구원수","가구원수"],
               ["소계","남","여","만10대미만","만10-19세","만20-29세","만30-39세","만40-49세","만50-59세","만60-69세","만70세이상",
                "소득없음","50만원미만","50-100만원미만","100-200만원미만","200-300만원미만","300-400만원미만","400-500만원미만","500만원이상",
                "서울","부산","대구","인천","광주","대전","울산","경기","강원","충북","충남","전북","전남","경북","경남","제주","세종",
                "1인가구","2인가구","3인이상가구"]]

# %%
ott_have=best_ott.T
ott_have
# Out:
#                      2019                2020
#                       사례수    있다    없다     사례수    있다    없다
# 전체    소계           4457.7  10.4  89.6  7434.0  14.4  85.6
# 성별    남            2375.6   9.5  90.5  3872.0  14.2  85.8
#       여            2082.1  11.6  88.4  3562.0  14.5  85.5
# 연령    만10대미만         80.6   1.2  98.8   173.0   0.5  99.5
#       만10-19세       501.5   5.1  94.9   825.0   5.4  94.6
#       만20-29세      1022.5  18.7  81.3  1378.0  25.4  74.6
#       만30-39세       978.7  11.8  88.2  1420.0  25.2  74.8
#       만40-49세       867.8   7.9  92.1  1481.0  15.1  84.9
#       만50-59세       683.8   7.2  92.8  1373.0   5.5  94.5
#       만60-69세       273.7   5.0  95.0   666.0   2.2  97.8
#       만70세이상         49.1   3.8  96.2   119.0   1.4  98.6
# 월평균소득 소득없음         1537.6   7.4  92.6  2477.0   9.0  91.0
#       50만원미만        105.8  24.3  75.7   138.0  20.7  79.3
#       50-100만원미만    136.8  14.5  85.5   222.0   9.6  90.4
#       100-200만원미만   800.5   8.0  92.0  1120.0   9.1  90.9
#       200-300만원미만  1081.3  13.8  86.2  1961.0  20.3  79.7
#       300-400만원미만   504.8  13.7  86.3  1026.0  21.6  78.4
#       400-500만원미만   173.2   7.9  92.1   266.0  18.2  81.8
#       500만원이상       117.7   9.2  90.8   224.0  10.8  89.2
# 지역    서울            699.2  14.9  85.1  1482.0  21.0  79.0
#       부산            393.5   3.5  96.5   524.0   6.8  93.2
#       대구            174.1  11.8  88.2   335.0  22.4  77.6
#       인천            245.4  10.3  89.7   452.0  15.1  84.9
#       광주            109.9   7.9  92.1   248.0  14.9  85.1
#       대전            230.3   6.0  94.0   213.0   4.0  96.0
#       울산            150.5  10.1  89.9   176.0  18.5  81.5
#       경기           1040.9  16.7  83.3  1907.0  14.3  85.7
#       강원            105.1  10.0  90.0   181.0  16.3  83.7
#       충북            249.7   1.1  98.9   264.0   8.1  91.9
#       충남            311.6   2.5  97.5   265.0   6.4  93.6
#       전북            139.4   4.1  95.9   262.0  14.6  85.4
#       전남             45.0  16.6  83.4   245.0   8.7  91.3
#       경북            135.2  15.4  84.6   291.0  15.7  84.3
#       경남            323.3  10.3  89.7   427.0   5.5  94.5
#       제주             58.9   3.5  96.5    83.0  22.2  77.8
#       세종             45.6   1.0  99.0    79.0  14.7  85.3
# 가구원수  1인가구          441.3  14.2  85.8   822.0  26.8  73.2
#       2인가구          919.5   9.5  90.5  1586.0  14.2  85.8
#       3인이상가구       3096.9  10.2  89.8  5027.0  12.4  87.6

# %% [markdown]
# ## 안됨....

# %%
ott_have2=ott_have.T

# %%
plt.pie(ott_have2["전체"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [177], in <cell line: 1>()
# ----> 1 plt.pie(ott_have2["전체"])
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2744, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2737 @_copy_docstring_and_deprecators(Axes.pie)
#    2738 def pie(
#    2739         x, explode=None, labels=None, colors=None, autopct=None,
#    (...)
#    2742         textprops=None, center=(0, 0), frame=False,
#    2743         rotatelabels=False, *, normalize=True, data=None):
# -> 2744     return gca().pie(
#    2745         x, explode=explode, labels=labels, colors=colors,
#    2746         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#    2747         labeldistance=labeldistance, startangle=startangle,
#    2748         radius=radius, counterclock=counterclock,
#    2749         wedgeprops=wedgeprops, textprops=textprops, center=center,
#    2750         frame=frame, rotatelabels=rotatelabels, normalize=normalize,
#    2751         **({"data": data} if data is not None else {}))
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:3044, in Axes.pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize)
#    3042 x = np.asarray(x, np.float32)
#    3043 if x.ndim > 1:
# -> 3044     raise ValueError("x must be 1D")
#    3046 if np.any(x < 0):
#    3047     raise ValueError("Wedge sizes 'x' must be non negative values")
#
# ValueError: x must be 1D

# %%
del (ott_have["2019","사례수"],ott_have["2020","사례수"])

# %%
ott_have["2019"].loc["전체"].T.plot(kind="pie")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [160], in <cell line: 1>()
# ----> 1 ott_have["2019"].loc["전체"].T.plot(kind="pie")
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_core.py:923, in PlotAccessor.__call__(self, *args, **kwargs)
#     921 if isinstance(data, ABCDataFrame):
#     922     if y is None and kwargs.get("subplots") is False:
# --> 923         raise ValueError(
#     924             f"{kind} requires either y column or 'subplots=True'"
#     925         )
#     926     elif y is not None:
#     927         if is_integer(y) and not data.columns.holds_integer():
#
# ValueError: pie requires either y column or 'subplots=True'

# %%
plt.pie(ott_have["2019"].loc["전체"].T)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [172], in <cell line: 1>()
# ----> 1 plt.pie(ott_have["2019"].loc["전체"].T)
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2744, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2737 @_copy_docstring_and_deprecators(Axes.pie)
#    2738 def pie(
#    2739         x, explode=None, labels=None, colors=None, autopct=None,
#    (...)
#    2742         textprops=None, center=(0, 0), frame=False,
#    2743         rotatelabels=False, *, normalize=True, data=None):
# -> 2744     return gca().pie(
#    2745         x, explode=explode, labels=labels, colors=colors,
#    2746         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#    2747         labeldistance=labeldistance, startangle=startangle,
#    2748         radius=radius, counterclock=counterclock,
#    2749         wedgeprops=wedgeprops, textprops=textprops, center=center,
#    2750         frame=frame, rotatelabels=rotatelabels, normalize=normalize,
#    2751         **({"data": data} if data is not None else {}))
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:3044, in Axes.pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize)
#    3042 x = np.asarray(x, np.float32)
#    3043 if x.ndim > 1:
# -> 3044     raise ValueError("x must be 1D")
#    3046 if np.any(x < 0):
#    3047     raise ValueError("Wedge sizes 'x' must be non negative values")
#
# ValueError: x must be 1D

# %% [markdown]
# # 5. 지출금액

# %%
best_ott = pd.read_csv("data/OTT서비스_월평균_지출_금액.csv",header=[0,1], index_col=[0,1])
best_ott
# Out:
# 구분별(1)               2020                                                  \
# 구분별(1)            사례수 (명) 5천원 미만 (%) 5천원 - 1만원 미만 (%) 1만원 - 1만 5천원 미만 (%)
# 전체      소계         1068.0        5.9             29.3                39.5
# 성별      남           551.0        5.8             27.3                41.0
#         여           517.0        5.9             31.4                38.0
# 연령      만10대미만        1.0        0.0              0.0               100.0
#         만10-19세      45.0        8.6             18.8                52.8
# ...                   ...        ...              ...                 ...
# 가구주와의관계 가구주의배우자     186.0        1.7             26.4                41.9
#         가구주의자녀      387.0        8.4             27.5                40.1
#         자녀의배우자        3.0       22.8             18.3                58.9
#         손자.녀/그배우자    11.0       17.4             55.0                 0.0
#         형제자매/그배우자    18.0       39.7              0.0                25.1
#
# 구분별(1)                                                                         \
# 구분별(1)            1만 5천원 - 2만원 미만 (%) 2만원 - 2만 5천원 미만 (%) 2만 5천원 - 3만원 미만 (%)
# 전체      소계                       14.6                 6.5                 1.2
# 성별      남                        14.5                 6.1                 1.7
#         여                        14.7                 7.0                 0.8
# 연령      만10대미만                    0.0                 0.0                 0.0
#         만10-19세                  11.9                 4.1                 1.4
# ...                               ...                 ...                 ...
# 가구주와의관계 가구주의배우자                  15.7                10.8                 0.5
#         가구주의자녀                   13.7                 4.6                 2.0
#         자녀의배우자                    0.0                 0.0                 0.0
#         손자.녀/그배우자                 9.1                 0.0                 0.0
#         형제자매/그배우자                 0.0                35.2                 0.0
#
# 구분별(1)
# 구분별(1)            3만원 - 3만 5천원 미만 (%) 3만 5천원 이상 (%)
# 전체      소계                        1.4           1.5
# 성별      남                         2.3           1.3
#         여                         0.4           1.7
# 연령      만10대미만                    0.0           0.0
#         만10-19세                   0.4           2.1
# ...                               ...           ...
# 가구주와의관계 가구주의배우자                   1.9           1.2
#         가구주의자녀                    2.1           1.7
#         자녀의배우자                    0.0           0.0
#         손자.녀/그배우자                 0.0          18.5
#         형제자매/그배우자                 0.0           0.0
#
# [79 rows x 9 columns]

# %%
best_ott.columns=[["2020","2020","2020","2020","2020","2020","2020","2020","2020"],
                 ["사례수","5천원 미만","5천-1만원 미만","1만-1.5만원 미만","1.5만-2만원미만","2만-2.5만원 미만",
                  "2.5만-3만원 미만","3만-3.5만원 미만","3.5만원 이상"]]

# %%
best_ott=best_ott.T

# %%
## 필요없는 컬럼 삭제

del (best_ott["학력1","초졸이하"],best_ott["학력1","중졸이하"],best_ott["학력1","고졸이하"],
     best_ott["학력1","대졸이하"],best_ott["학력1","대학원재학이상"])
del (best_ott["지역구분2", "시부"],best_ott["지역구분2", "군부"])
del (best_ott["종사상지위","임금근로자"],best_ott["종사상지위","고용주"],best_ott["종사상지위","단독자영업자"],
     best_ott["종사상지위","무급가족종사자"],best_ott["종사상지위","무직"])
del (best_ott["상세직업","관리자"],best_ott["상세직업","전문가및관련종사자"],best_ott["상세직업","사무종사자"],
     best_ott["상세직업","서비스종사자"],best_ott["상세직업","판매종사자"],best_ott["상세직업","농림어업종사자"],
     best_ott["상세직업","기능원및관련기능종사자"],best_ott["상세직업","장치기계조작및조립종사자"],best_ott["상세직업","단순노무종사자"],
     best_ott["상세직업","학생"],best_ott["상세직업","전업주부"],best_ott["상세직업","기타/무직"])
del (best_ott["주택형태","단독주택"],best_ott["주택형태","아파트"],best_ott["주택형태","연립주택빌라다세대주택"],
     best_ott["주택형태","비거주용건물내의주택"],best_ott["주택형태","기타"])
del (best_ott["가족구성","1인가구"],best_ott["가족구성","1세대가구"],best_ott["가족구성","2세대가구"],
     best_ott["가족구성","3세대가구"],best_ott["가족구성","기타"])
del (best_ott["가구주와의관계","가구주"],best_ott["가구주와의관계","가구주의배우자"],best_ott["가구주와의관계","가구주의자녀"],
     best_ott["가구주와의관계","자녀의배우자"],best_ott["가구주와의관계","손자.녀/그배우자"],best_ott["가구주와의관계","형제자매/그배우자"])

# %%
## 컬럼 정리

best_ott.columns=[["전체","성별","성별","연령","연령","연령","연령","연령","연령","연령","연령",
                "월평균소득","월평균소득","월평균소득","월평균소득","월평균소득","월평균소득","월평균소득","월평균소득",
                "지역","지역","지역","지역","지역","지역","지역","지역","지역","지역","지역","지역",
                "지역","지역","지역","지역","지역","가구원수","가구원수","가구원수"],
               ["소계","남","여","만10대미만","만10-19세","만20-29세","만30-39세","만40-49세","만50-59세","만60-69세","만70세이상",
                "소득없음","50만원미만","50-100만원미만","100-200만원미만","200-300만원미만","300-400만원미만","400-500만원미만","500만원이상",
                "서울","부산","대구","인천","광주","대전","울산","경기","강원","충북","충남","전북","전남","경북","경남","제주","세종",
                "1인가구","2인가구","3인이상가구"]]

# %%
## 원상복귀
ott_price=best_ott.T
ott_price
# Out:
#                      2020                                                      \
#                       사례수 5천원 미만 5천-1만원 미만 1만-1.5만원 미만 1.5만-2만원미만 2만-2.5만원 미만
# 전체    소계           1068.0    5.9      29.3        39.5       14.6         6.5
# 성별    남             551.0    5.8      27.3        41.0       14.5         6.1
#       여             517.0    5.9      31.4        38.0       14.7         7.0
# 연령    만10대미만          1.0    0.0       0.0       100.0        0.0         0.0
#       만10-19세        45.0    8.6      18.8        52.8       11.9         4.1
#       만20-29세       349.0    8.5      28.6        32.3       16.6         8.6
#       만30-39세       357.0    5.8      31.2        39.6       14.8         4.0
#       만40-49세       223.0    2.3      28.6        47.3       10.6         9.0
#       만50-59세        76.0    3.9      37.7        35.4       15.6         4.4
#       만60-69세        15.0    0.0       3.9        63.2       28.1         0.0
#       만70세이상          2.0    0.0       0.0        81.3        0.0        18.7
# 월평균소득 소득없음          223.0    7.7      22.3        44.8       13.1         5.4
#       50만원미만         29.0   35.1      46.0        14.7        2.3         1.8
#       50-100만원미만     21.0    2.0      50.1        26.0       12.0         9.8
#       100-200만원미만   102.0    2.4      28.1        37.6       15.0        15.6
#       200-300만원미만   398.0    5.2      34.2        41.0       13.5         2.9
#       300-400만원미만   222.0    4.0      26.1        33.8       20.5        10.3
#       400-500만원미만    48.0    5.5      19.7        45.9       16.9         4.1
#       500만원이상        24.0    0.0      28.3        55.3        4.1        12.2
# 지역    서울            311.0    3.1      22.2        49.1       16.0         6.4
#       부산             35.0   36.7      46.4        16.9        0.0         0.0
#       대구             75.0    2.1      24.9        47.0       15.6         4.1
#       인천             68.0    3.1      39.4        32.5        9.2         4.0
#       광주             37.0    0.0      43.0        12.3       34.2        10.5
#       대전              9.0    2.5      35.8        51.6        6.4         3.6
#       울산             33.0    0.5      10.0        36.1        7.9        44.5
#       경기            272.0    2.8      35.3        45.3        9.7         4.7
#       강원             29.0    6.4      14.9        21.4       22.1         3.8
#       충북             21.0    0.0      73.7        14.7       11.5         0.0
#       충남             17.0    1.3      21.3        36.5       41.0         0.0
#       전북             38.0    4.1      47.8        14.6       21.4         0.0
#       전남             21.0    0.0      17.9        16.1       59.5         6.5
#       경북             46.0   41.0       6.0        32.4       18.4         1.7
#       경남             23.0   10.9      60.0        26.0        3.1         0.0
#       제주             19.0   15.8       1.9        60.7        1.7        17.7
#       세종             12.0    1.9       2.6        42.4        0.0        53.1
# 가구원수  1인가구          220.0    0.0      41.1        43.0       10.7         3.2
#       2인가구          225.0    7.5      24.8        28.1       19.6        14.8
#       3인이상가구        623.0    7.3      26.8        42.4       14.2         4.8
#
#
#                   2.5만-3만원 미만 3만-3.5만원 미만 3.5만원 이상
# 전체    소계                  1.2         1.4      1.5
# 성별    남                   1.7         2.3      1.3
#       여                   0.8         0.4      1.7
# 연령    만10대미만              0.0         0.0      0.0
#       만10-19세             1.4         0.4      2.1
#       만20-29세             1.8         2.0      1.5
#       만30-39세             0.7         1.7      2.0
#       만40-49세             1.3         0.5      0.3
#       만50-59세             0.0         0.4      2.6
#       만60-69세             4.8         0.0      0.0
#       만70세이상              0.0         0.0      0.0
# 월평균소득 소득없음                0.8         3.2      2.6
#       50만원미만              0.0         0.0      0.0
#       50-100만원미만          0.0         0.0      0.0
#       100-200만원미만         0.0         0.5      0.8
#       200-300만원미만         1.4         1.4      0.3
#       300-400만원미만         2.3         0.1      2.8
#       400-500만원미만         1.5         2.4      4.0
#       500만원이상             0.0         0.0      0.0
# 지역    서울                  1.3         0.9      1.1
#       부산                  0.0         0.0      0.0
#       대구                  0.0         0.7      5.7
#       인천                  9.2         0.0      2.6
#       광주                  0.0         0.0      0.0
#       대전                  0.0         0.0      0.0
#       울산                  0.0         0.0      1.1
#       경기                  0.8         0.9      0.5
#       강원                  2.1        29.3      0.0
#       충북                  0.0         0.0      0.0
#       충남                  0.0         0.0      0.0
#       전북                  0.0         0.0     12.1
#       전남                  0.0         0.0      0.0
#       경북                  0.0         0.5      0.0
#       경남                  0.0         0.0      0.0
#       제주                  0.0         0.9      1.3
#       세종                  0.0         0.0      0.0
# 가구원수  1인가구                0.0         0.0      2.1
#       2인가구                0.6         4.7      0.0
#       3인이상가구              1.9         0.7      1.8

# %%
ott_price_1=ott_price.loc["월평균소득"]

# %%
del ott_price_1["2020","사례수"]

# %%
# 전체적으로 5천-1만원 이나 1만-1.5만원 정도의 지출이 많다1
ott_price_1.plot(kind='barh', stacked=True,figsize=(15,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 6. 영화관 관람객수

# %%
df=pd.DataFrame({"관객수":[112296315,39492860,16736764],
                 "스크린수":[61205,42133,27609],
                 "상영횟수":[3239500,2362506,1375818]})
df.index=["2019","2020","2021"]
df
# Out:
#             관객수   스크린수     상영횟수
# 2019  112296315  61205  3239500
# 2020   39492860  42133  2362506
# 2021   16736764  27609  1375818

# %%
df["관객수"].plot()

# 영화관 관람객 수 감소
# Out:
# <AxesSubplot:>
